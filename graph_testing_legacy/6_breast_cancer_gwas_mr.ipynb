# %%
import pandas as pd
import json
from environs import Env
from graph_functions import query_to_df,start_graph_session, start_graph_session_crashdown_w_auth
from IPython.display import Image


env = Env()
#session = start_graph_session(env) 
session = start_graph_session_crashdown_w_auth(env)
# Out:
# 38687

# %% [markdown]
# ## List of all breast-related GWAS

# %%
query="""
MATCH (gwas:Gwas)
where toLower(gwas.trait) contains "breast"
and not(toLower(gwas.trait) contains "baby") 
and not(toLower(gwas.trait) contains "mother")
and not(toLower(gwas.trait) contains "sibling")
and not(toLower(gwas.trait) contains "mammogram")
return distinct gwas.trait, gwas.id, gwas.sample_size as SampleSize,
toInteger(gwas.ncase) as N_case, toInteger(gwas.ncontrol) as N_control, gwas.author, gwas.year, gwas.consortium
order by SampleSize desc
"""
df = query_to_df(session, query)
#df.to_csv("query_results/bc_all_related_gwas.tsv", sep="\t", index=False)
df
# Out:
# MATCH (gwas:Gwas)
# where toLower(gwas.trait) contains "breast"
# and not(toLower(gwas.trait) contains "baby")
# and not(toLower(gwas.trait) contains "mother")
# and not(toLower(gwas.trait) contains "sibling")
# and not(toLower(gwas.trait) contains "mammogram")
# return distinct gwas.trait, gwas.id, gwas.sample_size as SampleSize,
# toInteger(gwas.ncase) as N_case, toInteger(gwas.ncontrol) as N_control, gwas.author, gwas.year, gwas.consortium
# order by SampleSize desc
#                                            gwas.trait  \
# 0                           Other disorders of breast
# 1                        Malignant neoplasm of breast
# 2                        Malignant neoplasm of breast
# 3        Carcinoma in situ of breast (ICD C excluded)
# 4                         Carcinoma in situ of breast
# ..                                                ...
# 65                           ER- Breast cancer (GWAS)
# 66  ER+ Breast cancer (Combined Oncoarray; iCOGS; ...
# 67                                      Breast cancer
# 68  ER- Breast cancer (Combined Oncoarray; iCOGS; ...
# 69                          Breast cancer (Oncoarray)
#
#                             gwas.id SampleSize   N_case  N_control  \
# 0           finn-a-N14_BREASTDISOTH       None    594.0    50767.0
# 1                  finn-a-C3_BREAST       None   2589.0    93910.0
# 2                finn-a-C3_BREAST_3       None   2589.0    93910.0
# 3   finn-a-CD2_INSITU_BREAST_EXALLC       None    377.0    87024.0
# 4          finn-a-CD2_INSITU_BREAST       None    377.0    96122.0
# ..                              ...        ...      ...        ...
# 65                       ieu-a-1166    21695.0   3611.0    18084.0
# 66                       ieu-a-1127   175475.0  69501.0   105974.0
# 67                 ebi-a-GCST004988   139274.0  76192.0    63082.0
# 68                       ieu-a-1128   127442.0  21468.0   105974.0
# 69                       ieu-a-1129   106776.0  61282.0    45494.0
#
#       gwas.author gwas.year gwas.consortium
# 0            None    2020.0            None
# 1            None    2020.0            None
# 2            None    2020.0            None
# 3            None    2020.0            None
# 4            None    2020.0            None
# ..            ...       ...             ...
# 65  Michailidou K    2015.0            BCAC
# 66  Michailidou K    2017.0            BCAC
# 67  Michailidou K    2017.0            None
# 68  Michailidou K    2017.0            BCAC
# 69  Michailidou K    2017.0            BCAC
#
# [70 rows x 8 columns]

# %% [markdown]
# ## Get BC GWAS that have MR results + exclude unrelated

# %%
query="""
MATCH (gwas:Gwas)<-[mr:MR_EVE_MR]-(othergwas:Gwas)
where toLower(gwas.trait) contains "breast"
    and not(toLower(gwas.trait) contains "baby") 
    and not(toLower(gwas.trait) contains "mother")
    and not(toLower(gwas.trait) contains "sibling")
    and not(toLower(gwas.trait) contains "mammogram")
    and not(toLower(gwas.trait) contains "protein")
return distinct gwas.trait, gwas.id, toInteger(gwas.sample_size) as SampleSize,
toInteger(gwas.ncase) as N_case, toInteger(gwas.ncontrol) as N_control, gwas.author, gwas.year, gwas.consortium
order by gwas.id,  gwas.author, N_case desc
"""
df = query_to_df(session, query)
#df.to_csv("query_results/bc_gwas_with_mr.tsv", sep="\t", index=False)

# calulate cases % in the dataset and only keep those >2%
df['case_percent'] = df['N_case']/df['SampleSize']*100
df = df[df['case_percent'] > 2]


#df.to_csv("query_results/bc_gwas_with_mr_keep.tsv", sep="\t", index=False)
all_bc_gwas = list(df['gwas.id'])
df
# Out:
# MATCH (gwas:Gwas)<-[mr:MR_EVE_MR]-(othergwas:Gwas)
# where toLower(gwas.trait) contains "breast"
#     and not(toLower(gwas.trait) contains "baby")
#     and not(toLower(gwas.trait) contains "mother")
#     and not(toLower(gwas.trait) contains "sibling")
#     and not(toLower(gwas.trait) contains "mammogram")
#     and not(toLower(gwas.trait) contains "protein")
# return distinct gwas.trait, gwas.id, toInteger(gwas.sample_size) as SampleSize,
# toInteger(gwas.ncase) as N_case, toInteger(gwas.ncontrol) as N_control, gwas.author, gwas.year, gwas.consortium
# order by gwas.id,  gwas.author, N_case desc
#                                            gwas.trait            gwas.id  \
# 0                                       Breast cancer   ebi-a-GCST004988
# 1                                       Breast cancer   ebi-a-GCST007236
# 2   Breast cancer (Combined Oncoarray; iCOGS; GWAS...         ieu-a-1126
# 3   ER+ Breast cancer (Combined Oncoarray; iCOGS; ...         ieu-a-1127
# 4   ER- Breast cancer (Combined Oncoarray; iCOGS; ...         ieu-a-1128
# 5                           Breast cancer (Oncoarray)         ieu-a-1129
# 6                               Breast cancer (iCOGS)         ieu-a-1130
# 7                                Breast cancer (GWAS)         ieu-a-1131
# 8                       ER+ Breast cancer (Oncoarray)         ieu-a-1132
# 9                           ER+ Breast cancer (iCOGS)         ieu-a-1133
# 10                           ER+ Breast cancer (GWAS)         ieu-a-1134
# 11                      ER- Breast cancer (Oncoarray)         ieu-a-1135
# 12                          ER- Breast cancer (iCOGS)         ieu-a-1136
# 13                           ER- Breast cancer (GWAS)         ieu-a-1137
# 14                          ER- Breast cancer (iCOGS)         ieu-a-1160
# 15                          ER+ Breast cancer (iCOGS)         ieu-a-1161
# 16                              Breast cancer (iCOGS)         ieu-a-1162
# 17                       ER- Breast cancer (Survival)         ieu-a-1163
# 18                       ER+ Breast cancer (Survival)         ieu-a-1164
# 19                           Breast cancer (Survival)         ieu-a-1165
# 20                           ER- Breast cancer (GWAS)         ieu-a-1166
# 21                           ER+ Breast cancer (GWAS)         ieu-a-1167
# 22                               Breast cancer (GWAS)         ieu-a-1168
# 24          Cancer code  self-reported: breast cancer           ukb-a-55
# 30          Cancer code, self-reported: breast cancer        ukb-b-16890
# 47                       Malignant neoplasm of breast  ukb-d-C3_BREAST_3
#
#     SampleSize  N_case  N_control    gwas.author gwas.year gwas.consortium  \
# 0       139274   76192      63082  Michailidou K    2017.0            None
# 1        89677   46785      42892  Michailidou K    2015.0            None
# 2       228951  122977     105974  Michailidou K    2017.0            BCAC
# 3       175475   69501     105974  Michailidou K    2017.0            BCAC
# 4       127442   21468     105974  Michailidou K    2017.0            BCAC
# 5       106776   61282      45494  Michailidou K    2017.0            BCAC
# 6        89677   46785      42892  Michailidou K    2017.0            BCAC
# 7        32498   14910      17588  Michailidou K    2017.0            BCAC
# 8        83691   38197      45494  Michailidou K    2017.0            BCAC
# 9        69970   27078      42892  Michailidou K    2017.0            BCAC
# 10       21814    4226      17588  Michailidou K    2017.0            BCAC
# 11       55149    9655      45494  Michailidou K    2017.0            BCAC
# 12       50225    7333      42892  Michailidou K    2017.0            BCAC
# 13       22068    4480      17588  Michailidou K    2017.0            BCAC
# 14       50225    7333      42892  Michailidou K    2015.0            BCAC
# 15       69970   27078      42892  Michailidou K    2015.0            BCAC
# 16       89677   46785      42892  Michailidou K    2015.0            BCAC
# 17        6881     920       5961          Guo Q    2015.0            BCAC
# 18       23059    1333      21726          Guo Q    2015.0            BCAC
# 19       37954    2900      35054          Guo Q    2015.0            BCAC
# 20       21695    3611      18084  Michailidou K    2015.0            BCAC
# 21       22286    4202      18084  Michailidou K    2015.0            BCAC
# 22       33832   15748      18084  Michailidou K    2015.0            BCAC
# 24      337159    7480     329679          Neale    2017.0       Neale Lab
# 30      462933   10303     452630   Ben Elsworth    2018.0         MRC-IEU
# 47      361194    9721     351473      Neale lab    2018.0            None
#
#     case_percent
# 0      54.706550
# 1      52.170568
# 2      53.713240
# 3      39.607351
# 4      16.845310
# 5      57.393047
# 6      52.170568
# 7      45.879746
# 8      45.640511
# 9      38.699443
# 10     19.372880
# 11     17.507117
# 12     14.600299
# 13     20.300888
# 14     14.600299
# 15     38.699443
# 16     52.170568
# 17     13.370150
# 18      5.780823
# 19      7.640828
# 20     16.644388
# 21     18.854886
# 22     46.547647
# 24      2.218538
# 30      2.225592
# 47      2.691351

# %%
all_bc_gwas
# Out:
# ['ebi-a-GCST004988',
#  'ebi-a-GCST007236',
#  'ieu-a-1126',
#  'ieu-a-1127',
#  'ieu-a-1128',
#  'ieu-a-1129',
#  'ieu-a-1130',
#  'ieu-a-1131',
#  'ieu-a-1132',
#  'ieu-a-1133',
#  'ieu-a-1134',
#  'ieu-a-1135',
#  'ieu-a-1136',
#  'ieu-a-1137',
#  'ieu-a-1160',
#  'ieu-a-1161',
#  'ieu-a-1162',
#  'ieu-a-1163',
#  'ieu-a-1164',
#  'ieu-a-1165',
#  'ieu-a-1166',
#  'ieu-a-1167',
#  'ieu-a-1168',
#  'ukb-a-55',
#  'ukb-b-16890',
#  'ukb-d-C3_BREAST_3']

# %%
# ebi-a-GCST007236 data is messed up - exclude
all_bc_gwas.remove('ebi-a-GCST007236')
all_bc_gwas.remove('ebi-a-GCST004988')
print(all_bc_gwas)
# Out:
# ['ieu-a-1126', 'ieu-a-1127', 'ieu-a-1128', 'ieu-a-1129', 'ieu-a-1130', 'ieu-a-1131', 'ieu-a-1132', 'ieu-a-1133', 'ieu-a-1134', 'ieu-a-1135', 'ieu-a-1136', 'ieu-a-1137', 'ieu-a-1160', 'ieu-a-1161', 'ieu-a-1162', 'ieu-a-1163', 'ieu-a-1164', 'ieu-a-1165', 'ieu-a-1166', 'ieu-a-1167', 'ieu-a-1168', 'ukb-a-55', 'ukb-b-16890', 'ukb-d-C3_BREAST_3']

# %% [markdown]
# ## Review MR data for the main dataset

# %%
# MR test
query = """
MATCH (exposure:Gwas)-[mr:MR_EVE_MR]->(outcome:Gwas)
WHERE outcome.id = "ieu-a-1126"  
AND (not (toLower(exposure.trait) contains 'breast')) 
AND mr.pval < 1e-05
RETURN exposure {.id, .trait}, outcome.id, mr {.b, .pval, .method, .selection, .moescore} ORDER BY mr.pval
"""
df = query_to_df(session, query)
df
# Out:
# MATCH (exposure:Gwas)-[mr:MR_EVE_MR]->(outcome:Gwas)
# WHERE outcome.id = "ieu-a-1126"
# AND (not (toLower(exposure.trait) contains 'breast'))
# AND mr.pval < 1e-05
# RETURN exposure {.id, .trait}, outcome.id, mr {.b, .pval, .method, .selection, .moescore} ORDER BY mr.pval
#     outcome.id                                     exposure.trait  \
# 0   ieu-a-1126                           Ever addicted to alcohol
# 1   ieu-a-1126  Diagnoses - secondary ICD10: K44.9 Diaphragmat...
# 2   ieu-a-1126     Killer cell immunoglobulin-like receptor 2DL5A
# 3   ieu-a-1126               Ever had hysterectomy (womb removed)
# 4   ieu-a-1126       Operation code: bunion/hallus valgus surgery
# 5   ieu-a-1126  Vascular endothelial growth factor A, isoform 121
# 6   ieu-a-1126                       fatty acid binding protein 4
# 7   ieu-a-1126  Diagnoses - secondary ICD10: Z92.1 Personal hi...
# 8   ieu-a-1126  CUB and zona pellucida-like domain-containing ...
# 9   ieu-a-1126                                          Filamin-A
# 10  ieu-a-1126                                Alpha-L-iduronidase
# 11  ieu-a-1126                Secretory phospholipase A2 receptor
# 12  ieu-a-1126                                    HDL cholesterol
# 13  ieu-a-1126                                            X-11440
# 14  ieu-a-1126                                  Childhood obesity
# 15  ieu-a-1126                             Falls in the last year
# 16  ieu-a-1126                               Delta-like protein 1
# 17  ieu-a-1126                   Cadherin-related family member 3
# 18  ieu-a-1126  Completion status of test: Heart rate reached ...
# 19  ieu-a-1126  Non-cancer illness code, self-reported: ankylo...
# 20  ieu-a-1126                                    Body mass index
# 21  ieu-a-1126                             Added milk to espresso
# 22  ieu-a-1126  Parental longevity (combined parental age at d...
# 23  ieu-a-1126    Tyrosine-protein kinase receptor Tie-1, soluble
# 24  ieu-a-1126                      Xyloside xylosyltransferase 1
# 25  ieu-a-1126                                  Hip circumference
# 26  ieu-a-1126                                          Maspardin
# 27  ieu-a-1126  IDP dMRI TBSS ICVF Anterior limb of internal c...
# 28  ieu-a-1126                    IDP dMRI ProbtrackX ISOVF slf r
# 29  ieu-a-1126                                        Calpastatin
# 30  ieu-a-1126  Types of physical activity in last 4 weeks: No...
# 31  ieu-a-1126  Immunoglobulin superfamily containing leucine-...
# 32  ieu-a-1126           Age at menopause (last menstrual period)
# 33  ieu-a-1126         Retinoic acid receptor responder protein 1
# 34  ieu-a-1126                                Waist circumference
# 35  ieu-a-1126                IDP T1 FAST ROIs R ventral striatum
# 36  ieu-a-1126              IDP dMRI TBSS ICVF External capsule R
# 37  ieu-a-1126                              Interleukin-16 levels
# 38  ieu-a-1126                            Impedance of arm (left)
# 39  ieu-a-1126                     IDP T1 FAST ROIs R hippocampus
# 40  ieu-a-1126                       IDP dMRI ProbtrackX L1 unc r
# 41  ieu-a-1126              Operation code: carpal tunnel surgery
# 42  ieu-a-1126              IDP dMRI TBSS ICVF External capsule L
# 43  ieu-a-1126                           netmat ICA 09Aug2017 003
# 44  ieu-a-1126  IDP dMRI TBSS ICVF Anterior limb of internal c...
# 45  ieu-a-1126                                             Height
# 46  ieu-a-1126                                    HDL cholesterol
# 47  ieu-a-1126                            Impedance of arm (left)
# 48  ieu-a-1126                                  Hip circumference
# 49  ieu-a-1126                                Number in household
# 50  ieu-a-1126  Complement C1q tumor necrosis factor-related p...
# 51  ieu-a-1126                           Impedance of leg (right)
# 52  ieu-a-1126                                Parkinson's disease
# 53  ieu-a-1126                                     Time to answer
#
#          exposure.id      mr.b         mr.method mr.selection        mr.pval  \
# 0        ukb-d-20406 -0.054825            FE IVW           DF   0.000000e+00
# 1         ukb-b-3672 -1.542995            FE IVW           DF  4.514856e-242
# 2        prot-a-1644  0.016679            FE IVW           DF  4.770365e-106
# 3         ukb-b-6445 -1.562231            FE IVW           DF   9.686474e-86
# 4         ukb-b-9190  1.109370            FE IVW           DF   3.334299e-85
# 5        prot-a-3197  0.013410            FE IVW           DF   7.992747e-83
# 6          prot-b-71  0.019159            FE IVW           DF   1.571455e-58
# 7         ukb-b-7352 -0.973106            FE IVW           DF   1.267170e-57
# 8         prot-a-735  0.021479            FE IVW           DF   2.941390e-37
# 9        prot-a-1117 -0.054938            FE IVW           DF   9.719336e-26
# 10       prot-a-1411  0.022690            FE IVW           DF   4.120827e-25
# 11       prot-a-2291  0.014897            FE IVW           DF   8.347529e-25
# 12  ebi-a-GCST005058  0.058877            FE IVW           DF   1.163784e-19
# 13         met-a-513 -0.113873            FE IVW           DF   1.321509e-19
# 14        ieu-a-1096 -0.199101            FE IVW           DF   1.726210e-18
# 15        ukb-b-2535  1.278313            FE IVW           DF   3.494507e-16
# 16        prot-a-831  0.053920            FE IVW           DF   6.557481e-16
# 17        prot-a-488 -0.088639            FE IVW           DF   1.358433e-15
# 18     ukb-d-6020_33 -0.653432            FE IVW           DF   2.380744e-15
# 19       ukb-b-18194  1.662842            FE IVW           DF   2.066378e-14
# 20         ieu-a-974 -0.788037          FE Egger           HF   9.788118e-13
# 21        ukb-b-1004  0.867059            FE IVW           DF   3.788631e-12
# 22  ebi-a-GCST006702  0.526232            FE IVW           HF   2.541637e-11
# 23       prot-a-2978 -0.031356            FE IVW           DF   2.783312e-11
# 24       prot-a-3243  0.050365            FE IVW           DF   5.800064e-11
# 25          ieu-a-99 -0.571581            FE IVW           DF   6.247788e-11
# 26       prot-a-2815 -0.016165            FE IVW           DF   3.624044e-10
# 27         ubm-a-501  0.058488            FE IVW           DF   1.048454e-09
# 28         ubm-a-866 -0.050763            FE IVW           DF   2.597902e-09
# 29        prot-a-366  0.054911            FE IVW           DF   3.406328e-09
# 30         ukb-a-483  3.564379            FE IVW           HF   4.223489e-09
# 31       prot-a-1576 -0.079188            FE IVW           DF   1.003360e-08
# 32       ukb-b-17422  0.187735   Weighted median      Tophits   1.174988e-08
# 33       prot-a-2493 -0.007965            FE IVW           DF   1.370085e-08
# 34          ieu-a-68 -0.395373  Penalised median           HF   1.646781e-08
# 35         ubm-a-135  0.053819            FE IVW           DF   2.476054e-08
# 36         ubm-a-516  0.047657            FE IVW           DF   3.079077e-08
# 37  ebi-a-GCST004430  0.019195            FE IVW           DF   3.167074e-08
# 38         ukb-a-273  0.155830            FE IVW      Tophits   6.049757e-08
# 39         ubm-a-131  0.472672            FE IVW           DF   9.494311e-08
# 40         ubm-a-735 -0.049616            FE IVW           DF   1.299429e-07
# 41       ukb-b-17788  1.519196            FE IVW           DF   2.533744e-07
# 42         ubm-a-517  0.047683            FE IVW           DF   4.310607e-07
# 43        ubm-a-3143 -0.063051            FE IVW           DF   4.395737e-07
# 44         ubm-a-500  0.062689            FE IVW           DF   7.980397e-07
# 45        ieu-a-1034  0.224204            FE IVW           DF   9.450253e-07
# 46  ukb-d-30760_irnt  0.136435  Penalised median           DF   1.071715e-06
# 47       ukb-b-19379  0.155514       Simple mean           HF   1.169473e-06
# 48         ieu-a-101  0.300115            FE IVW           DF   3.831879e-06
# 49        ukb-b-5445 -1.181082            FE IVW           DF   5.908395e-06
# 50        prot-a-305 -0.083802            FE IVW           DF   6.316824e-06
# 51        ukb-b-7376  0.105088       Simple mean           HF   8.297733e-06
# 52         ieu-a-812  0.058860            FE IVW           DF   8.649386e-06
# 53       ukb-b-14360  1.105045            FE IVW           DF   9.654924e-06
#
#     mr.moescore
# 0          1.00
# 1          1.00
# 2          1.00
# 3          1.00
# 4          1.00
# 5          1.00
# 6          1.00
# 7          1.00
# 8          1.00
# 9          1.00
# 10         1.00
# 11         1.00
# 12         1.00
# 13         1.00
# 14         1.00
# 15         1.00
# 16         1.00
# 17         1.00
# 18         1.00
# 19         1.00
# 20         0.76
# 21         1.00
# 22         0.73
# 23         1.00
# 24         1.00
# 25         1.00
# 26         1.00
# 27         1.00
# 28         1.00
# 29         1.00
# 30         0.71
# 31         1.00
# 32         0.83
# 33         1.00
# 34         0.72
# 35         1.00
# 36         1.00
# 37         1.00
# 38         0.67
# 39         1.00
# 40         1.00
# 41         1.00
# 42         1.00
# 43         1.00
# 44         1.00
# 45         1.00
# 46         0.69
# 47         0.74
# 48         1.00
# 49         1.00
# 50         1.00
# 51         0.71
# 52         1.00
# 53         1.00

# %%
# NB takes a long time
# MR
# get traits that have pval < 1e-05

query = """
    MATCH (exposure:Gwas)-[mr:MR_EVE_MR]->(outcome:Gwas)
    WHERE outcome.id in {gwas_list} 
    AND  not exposure.id  in {gwas_list}
    AND (not (toLower(exposure.trait) contains 'breast')) 
    AND mr.pval < 1e-05
    with mr, exposure, outcome
    ORDER BY mr.pval 
    RETURN exposure.id, exposure.trait, exposure.sample_size,
            collect(outcome.id) as outcome_ids, 
            collect(mr.pval) as MR_pvals, collect(mr.b) as MR_beta

""".format(gwas_list = all_bc_gwas)
df = query_to_df(session, query, True)

df
# Out:
#     MATCH (exposure:Gwas)-[mr:MR_EVE_MR]->(outcome:Gwas)
#     WHERE outcome.id in ['ieu-a-1126', 'ieu-a-1127', 'ieu-a-1128', 'ieu-a-1129', 'ieu-a-1130', 'ieu-a-1131', 'ieu-a-1132', 'ieu-a-1133', 'ieu-a-1134', 'ieu-a-1135', 'ieu-a-1136', 'ieu-a-1137', 'ieu-a-1160', 'ieu-a-1161', 'ieu-a-1162', 'ieu-a-1163', 'ieu-a-1164', 'ieu-a-1165', 'ieu-a-1166', 'ieu-a-1167', 'ieu-a-1168', 'ukb-a-55', 'ukb-b-16890', 'ukb-d-C3_BREAST_3']
#     AND  not exposure.id  in ['ieu-a-1126', 'ieu-a-1127', 'ieu-a-1128', 'ieu-a-1129', 'ieu-a-1130', 'ieu-a-1131', 'ieu-a-1132', 'ieu-a-1133', 'ieu-a-1134', 'ieu-a-1135', 'ieu-a-1136', 'ieu-a-1137', 'ieu-a-1160', 'ieu-a-1161', 'ieu-a-1162', 'ieu-a-1163', 'ieu-a-1164', 'ieu-a-1165', 'ieu-a-1166', 'ieu-a-1167', 'ieu-a-1168', 'ukb-a-55', 'ukb-b-16890', 'ukb-d-C3_BREAST_3']
#     AND (not (toLower(exposure.trait) contains 'breast'))
#     AND mr.pval < 1e-05
#     with mr, exposure, outcome
#     ORDER BY mr.pval
#     RETURN exposure.id, exposure.trait, exposure.sample_size,
#             collect(outcome.id) as outcome_ids,
#             collect(mr.pval) as MR_pvals, collect(mr.b) as MR_beta
#      exposure.id                                     exposure.trait  \
# 0    prot-a-1411                                Alpha-L-iduronidase
# 1    prot-a-1276             Glutamate receptor ionotropic, delta-2
# 2    prot-a-2166  Platelet-activating factor acetylhydrolase IB ...
# 3     prot-a-995                            Protein eva-1 homolog C
# 4     prot-a-566                             Creatine kinase M-type
# ..           ...                                                ...
# 737   prot-a-821                         Dickkopf-related protein 1
# 738   ukb-b-7376                           Impedance of leg (right)
# 739  ukb-b-15782                              logMAR, final (right)
# 740    ieu-a-812                                Parkinson's disease
# 741     ieu-a-22                                      Schizophrenia
#
#     exposure.sample_size                                        outcome_ids  \
# 0                 3301.0  [ukb-b-16890, ieu-a-1136, ieu-a-1126, ieu-a-11...
# 1                 3301.0                                      [ukb-b-16890]
# 2                 3301.0                                      [ukb-b-16890]
# 3                 3301.0              [ukb-b-16890, ieu-a-1132, ieu-a-1127]
# 4                 3301.0                                      [ukb-b-16890]
# ..                   ...                                                ...
# 737               3301.0                                       [ieu-a-1136]
# 738             454863.0                                       [ieu-a-1126]
# 739             101023.0                                         [ukb-a-55]
# 740               5691.0                                       [ieu-a-1126]
# 741              82315.0                                       [ieu-a-1132]
#
#                                               MR_pvals  \
# 0    [0.0, 0.0, 4.12082678662007e-25, 1.62953109690...
# 1                                                [0.0]
# 2                                                [0.0]
# 3    [0.0, 1.71005705410616e-33, 9.05550305130723e-11]
# 4                                                [0.0]
# ..                                                 ...
# 737                             [8.24099097862065e-06]
# 738                             [8.29773347622307e-06]
# 739                             [8.52893962249346e-06]
# 740                             [8.64938636830279e-06]
# 741                              [8.8263705385911e-06]
#
#                                                MR_beta
# 0    [0.000454060802980906, 0.0167251457326905, 0.0...
# 1                                [0.00273122085407538]
# 2                              [-0.000697314107341724]
# 3    [0.00111999698219523, -0.0269001814975584, -0....
# 4                                [-0.0020934261149299]
# ..                                                 ...
# 737                               [0.0339189126254016]
# 738                                [0.105088281390953]
# 739                              [0.00588635442005368]
# 740                               [0.0588601942842277]
# 741                               [0.0589809881113837]
#
# [742 rows x 6 columns]

# %%
df.shape
# Out:
# (742, 6)

# %%
# now those traits that appered at least once in something at <1e05, 
# get MR results for those traits with all BC datasets

query = """
MATCH (exposure:Gwas)-[mr:MR_EVE_MR]->(outcome:Gwas)
WHERE outcome.id in {gwas_list} 
AND  exposure.id  in {exposure_list}
with mr, exposure, outcome
ORDER BY exposure.trait
RETURN exposure.id, exposure.trait, exposure.sample_size, exposure.sex, exposure.note,
toInteger(exposure.year) as year, exposure.author as author, exposure.consortium as consortium,
        outcome.id, outcome.sample_size, toInteger(outcome.ncase) as N_case, outcome.year, outcome.nsnp,
        mr.pval, mr.b, mr.se, mr.method, mr.moescore
""".format(gwas_list = all_bc_gwas,
           exposure_list = list(set(df['exposure.id'])))
df = query_to_df(session, query, True)


#df.to_csv("query_results/bc_all_mr.tsv", sep="\t", index=False)
#df.to_csv("query_results/bc_all_mr_allMR.tsv", sep="\t", index=False) with pval <1

df
# Out:
# MATCH (exposure:Gwas)-[mr:MR_EVE_MR]->(outcome:Gwas)
# WHERE outcome.id in ['ieu-a-1126', 'ieu-a-1127', 'ieu-a-1128', 'ieu-a-1129', 'ieu-a-1130', 'ieu-a-1131', 'ieu-a-1132', 'ieu-a-1133', 'ieu-a-1134', 'ieu-a-1135', 'ieu-a-1136', 'ieu-a-1137', 'ieu-a-1160', 'ieu-a-1161', 'ieu-a-1162', 'ieu-a-1163', 'ieu-a-1164', 'ieu-a-1165', 'ieu-a-1166', 'ieu-a-1167', 'ieu-a-1168', 'ukb-a-55', 'ukb-b-16890', 'ukb-d-C3_BREAST_3']
# AND  exposure.id  in ['ukb-b-16812', 'ieu-a-22', 'prot-a-2440', 'ubm-a-510', 'prot-a-2039', 'ukb-b-16677', 'prot-a-1288', 'ukb-b-8846', 'ubm-a-271', 'prot-a-1075', 'ieu-a-64', 'prot-a-2362', 'ukb-b-19520', 'prot-a-1833', 'ubm-a-613', 'prot-a-1930', 'ukb-a-243', 'prot-a-2557', 'prot-a-319', 'prot-a-2018', 'prot-a-212', 'ukb-b-2183', 'prot-a-3137', 'prot-a-3254', 'ukb-b-8297', 'ukb-d-G6_NERPLEX', 'ukb-b-10859', 'prot-a-1006', 'ubm-a-
 'ubm-a-476', 'prot-a-2739', 'ukb-b-10181', 'ieu-a-93', 'ebi-a-GCST000679', 'ubm-a-2656', 'ukb-b-4955', 'ukb-d-20500', 'ebi-a-GCST004623', 'ukb-a-75', 'ukb-a-572', 'prot-a-2978', 'ukb-b-13932', 'ukb-b-8778', 'prot-a-2795', 'ebi-a-GCST003770', 'prot-a-2030', 'prot-a-2900', 'ukb-b-15445', 'prot-a-1117', 'prot-a-1906', 'prot-a-2245', 'ukb-a-23', 'ukb-b-8133', 'ukb-b-11971', 'prot-a-2760', 'ukb-b-12209', 'met-c-855', 'ukb-b-8755', 'prot-a-674', 'ukb-a-343', 'ukb-b-3599', 'ukb-b-703', 'prot-a-1950', 'prot-a-2666', 'ukb-a-552', 'prot-a-2329', 'ukb-b-1744', 'prot-a-714', 'prot-a-2875', 'ukb-b-18799', 'prot-a-2350', 'prot-a-2247', 'prot-a-867', 'ukb-b-8865', 'ukb-d-II_NEOPLASM', 'prot-a-135', 'ubm-a-517', 'ukb-a-373', 'ukb-b-9127', 'ukb-b-6500', 'ieu-a-76', 'ukb-d-22506_114', 'ieu-a-999', 'ubm-a-550', 'ubm-a-327', 'ieu-a-55', 'prot-a-1921', 'prot-a-953', 'ukb-a-273', 'prot-a-1991', 'ukb-a-60', 'prot-a-2729', 'ubm-a-668', 'met-a-558', 'prot-a-1835', 'prot-a-1863', 'prot-a-2665', 'prot-a-1724', 'ieu-a-1051', 'ebi-a-GCST005327', 'ukb-b-16855', 'met-c-874', 'met-c-902', 'prot-a-37', 'ukb-a-454', 'ieu-a-836', 'prot-a-2878', 'prot-a-570', 'prot-a-3009', 'prot-a-1645', 'met-a-383', 'ukb-a-150', 'met-a-636', 'prot-a-2324', 'ukb-b-4711', 'prot-a-419', 'ukb-b-17422', 'ukb-b-16881', 'prot-a-1606', 'prot-a-2291', 'prot-a-2573', 'ukb-a-236', 'ukb-b-16886', 'ukb-b-1004', 'ukb-d-XVIII_MISCFINDINGS' ...
# with mr, exposure, outcome
# ORDER BY exposure.trait
# RETURN exposure.id, exposure.trait, exposure.sample_size, exposure.sex, exposure.note,
# toInteger(exposure.year) as year, exposure.author as author, exposure.consortium as consortium,
#         outcome.id, outcome.sample_size, toInteger(outcome.ncase) as N_case, outcome.year, outcome.nsnp,
#         mr.pval, mr.b, mr.se, mr.method, mr.moescore
#                        exposure.id                 exposure.trait  \
# 0      ukb-d-M13_POLYARTHROPATHIES             #Polyarthropathies
# 1      ukb-d-M13_POLYARTHROPATHIES             #Polyarthropathies
# 2      ukb-d-M13_POLYARTHROPATHIES             #Polyarthropathies
# 3      ukb-d-M13_POLYARTHROPATHIES             #Polyarthropathies
# 4      ukb-d-M13_POLYARTHROPATHIES             #Polyarthropathies
# ...                            ...                            ...
# 16180                   ubm-a-2656  volume Left-Lateral-Ventricle
# 16181                   ubm-a-2656  volume Left-Lateral-Ventricle
# 16182                   ubm-a-2656  volume Left-Lateral-Ventricle
# 16183                   ubm-a-2656  volume Left-Lateral-Ventricle
# 16184                   ubm-a-2656  volume Left-Lateral-Ventricle
#
#       exposure.sample_size       exposure.sex exposure.note  year      author  \
# 0                 361194.0  Males and Females          None  2018   Neale lab
# 1                 361194.0  Males and Females          None  2018   Neale lab
# 2                 361194.0  Males and Females          None  2018   Neale lab
# 3                 361194.0  Males and Females          None  2018   Neale lab
# 4                 361194.0  Males and Females          None  2018   Neale lab
# ...                    ...                ...           ...   ...         ...
# 16180               8411.0              Males          None  2018  Elliott LT
# 16181               8411.0              Males          None  2018  Elliott LT
# 16182               8411.0              Males          None  2018  Elliott LT
# 16183               8411.0              Males          None  2018  Elliott LT
# 16184               8411.0              Males          None  2018  Elliott LT
#
#       consortium  outcome.id outcome.sample_size  N_case outcome.year  \
# 0           None  ieu-a-1168             33832.0   15748       2015.0
# 1           None  ieu-a-1167             22286.0    4202       2015.0
# 2           None  ieu-a-1166             21695.0    3611       2015.0
# 3           None  ieu-a-1165             37954.0    2900       2015.0
# 4           None  ieu-a-1164             23059.0    1333       2015.0
# ...          ...         ...                 ...     ...          ...
# 16180       None  ieu-a-1130             89677.0   46785       2017.0
# 16181       None  ieu-a-1129            106776.0   61282       2017.0
# 16182       None  ieu-a-1128            127442.0   21468       2017.0
# 16183       None  ieu-a-1127            175475.0   69501       2017.0
# 16184       None  ieu-a-1126            228951.0  122977       2017.0
#
#       outcome.nsnp       mr.pval       mr.b      mr.se   mr.method  \
# 0       13011123.0  8.200307e-01  -0.692852   3.045429      FE IVW
# 1       13011123.0  5.000000e-01  -0.462777  -0.462777  Wald ratio
# 2       13011123.0  1.253699e-02   2.923434   1.170939      FE IVW
# 3       12940150.0  5.000000e-01   0.124119   0.124119  Wald ratio
# 4        8714606.0  5.000000e-01 -17.286818 -17.286818  Wald ratio
# ...            ...           ...        ...        ...         ...
# 16180   10680257.0  1.543810e-02   0.108434   0.044772      FE IVW
# 16181   10680257.0  1.285261e-90  -0.158745   0.007864      FE IVW
# 16182   10680257.0  2.196088e-01   0.041780   0.034035      FE IVW
# 16183   10680257.0  1.951276e-01  -0.094147   0.072669      FE IVW
# 16184   10680257.0  2.759776e-01  -0.066561   0.061099      FE IVW
#
#        mr.moescore
# 0              1.0
# 1              1.0
# 2              1.0
# 3              1.0
# 4              1.0
# ...            ...
# 16180          1.0
# 16181          1.0
# 16182          1.0
# 16183          1.0
# 16184          1.0
#
# [16185 rows x 18 columns]

# %%
df.shape
# Out:
# (16185, 18)

# %%
df.to_csv("../query_results/bc_all_mr_allMR.tsv", sep="\t", index=False)

# %% [markdown]
# ### Extract MR results for a list of exposure GWAS

# %%
# read list of exp gwas (EXTRACTED IN R)
risk_factors = list(pd.read_csv("../query_results/gwas_rf_list.txt", sep = '\t')['id'])


query = """
MATCH (exposure:Gwas)-[mr:MR_EVE_MR]->(outcome:Gwas)
WHERE outcome.id in {gwas_list_outcome} 
AND  exposure.id  in {gwas_list_exposure}
//AND mr.pval < 1e-05
with mr, exposure, outcome
ORDER BY exposure.trait
RETURN exposure.id, exposure.trait, exposure.sample_size, exposure.sex, exposure.note,
toInteger(exposure.year) as year, exposure.author as author, exposure.consortium as consortium,
        outcome.id, outcome.sample_size, toInteger(outcome.ncase) as N_case, outcome.year, outcome.nsnp,
        mr.pval, mr.b, mr.se, mr.method, mr.moescore
        
""".format(gwas_list_outcome = all_bc_gwas,
           gwas_list_exposure = risk_factors )
df = query_to_df(session, query, True)


#df.to_csv("query_results/gwas_rf_bc_all_mr.tsv", sep="\t", index=False)
df
# Out:
# MATCH (exposure:Gwas)-[mr:MR_EVE_MR]->(outcome:Gwas)
# WHERE outcome.id in None
# AND  exposure.id  in ['ukb-b-2115', 'ukb-b-19885', 'ukb-b-5764', 'ebi-a-GCST006100', 'ukb-a-511', 'ukb-a-4', 'ukb-b-4512', 'ukb-b-15869', 'ukb-b-8865', 'ukb-b-7663', 'ukb-b-6011', 'ukb-a-507', 'ukb-b-16998', 'ukb-b-2993', 'ukb-a-483', 'ukb-b-8764', 'ukb-b-4710', 'ukb-b-3502', 'ukb-b-151', 'ukb-a-485', 'ukb-b-13184', 'ukb-a-512', 'ebi-a-GCST006097', 'ukb-b-13702', 'ukb-a-486', 'ukb-b-12205', 'ukb-b-11495', 'ukb-a-509', 'ukb-a-508', 'ukb-a-349', 'ukb-a-350', 'ukb-a-1', 'ukb-b-7337', 'ukb-b-2346', 'ukb-b-14649', 'ukb-b-1046', 'ukb-a-396', 'ukb-b-18176', 'ukb-b-13932', 'ebi-a-GCST006098', 'ukb-a-484', 'ebi-a-GCST006099', 'ukb-b-9991', 'ukb-a-482', 'ukb-a-487', 'ukb-b-2634', 'ukb-a-312', 'ukb-b-9433', 'ukb-a-315', 'ukb-a-323', 'ukb-b-9487', 'ukb-b-8727', 'ukb-b-18105', 'ukb-b-12405', 'ukb-b-9509', 'ukb-b-3768', 'ukb-b-4564', 'ukb-b-4193', 'ukb-b-9547', 'ukb-b-17422', 'ieu-a-1004', 'ukb-a-322', 'ukb-a-319', 'ukb-b-8080', 'ukb-a-324', 'ukb-a-317', 'ukb-a-451', 'ukb-b-18541', 'ukb-b-4206', 'ukb-b-1209', 'ukb-a-316', 'ukb-a-320', 'ukb-b-16927', 'ieu-a-1095', 'ebi-a-GCST90000027', 'ebi-a-GCST90000025', 'ebi-a-GCST90000026', 'ieu-a-27', 'ieu-a-1083', 'ebi-a-GCST007557', 'ukb-a-198', 'ukb-b-13378', 'ukb-a-264', 'ukb-b-8909', 'ebi-a-GCST003435', 'ieu-b-40', 'ieu-a-974', 'ieu-a-835', 'ebi-a-GCST006802', 'ieu-a-1089', 'ebi-a-GCST006368', 'ieu-a-95', 'ebi-a-GCST002783', 'ukb-a-248', 'ukb-b-2303', 'ukb-b-19953', 'ieu-a-1096', 'ukb-a-34', 'ukb-b-4650', 'ukb-a-35', 'ukb-d-R22', 'ukb-b-13845', 'ieu-a-1040', 'ieu-a-1038', 'ieu-a-1035', 'ieu-a-1037', 'ieu-a-85', 'ieu-a-86', 'ieu-a-87', 'ukb-d-4979', 'ukb-b-13330', 'prot-a-18', 'ukb-d-20544_5', 'ieu-a-90', 'ieu-a-91', 'ieu-a-92', 'ebi-a-GCST005314', 'ieu-a-93', 'ukb-a-195', 'ukb-b-16881', 'ieu-a-1070', 'ieu-a-1071', 'ukb-a-389', 'ukb-b-10787', 'ukb-b-20044', 'ukb-a-291', 'ukb-a-290', 'ukb-b-16407', 'ukb-a-292', 'ukb-b-17409', 'ukb-a-293', 'ukb-b-9685', 'ieu-a-109', 'ieu-a-73', 'ieu-a-75', 'ieu-a-81', 'ieu-a-79', 'ieu-a-111', 'ukb-b-19393', 'ukb-a-265', 'ukb-a-266', 'ukb-b-13354', 'ukb-a-267', 'ukb-b-14540']
# //AND mr.pval < 1e-05
# with mr, exposure, outcome
# ORDER BY exposure.trait
# RETURN exposure.id, exposure.trait, exposure.sample_size, exposure.sex, exposure.note,
# toInteger(exposure.year) as year, exposure.author as author, exposure.consortium as consortium,
#         outcome.id, outcome.sample_size, toInteger(outcome.ncase) as N_case, outcome.year, outcome.nsnp,
#         mr.pval, mr.b, mr.se, mr.method, mr.moescore
# ---------------------------------------------------------------------------
# CypherSyntaxError                         Traceback (most recent call last)
# <ipython-input-6-9ecc9884f85a> in <module>
#      17 """.format(gwas_list_outcome = all_bc_gwas,
#      18            gwas_list_exposure = risk_factors )
# ---> 19 df = query_to_df(session, query, True)
#      20
#      21
#
# ~/Documents/Projects_IEU/epigraphdb_breast_cancer/python/graph_functions.py in query_to_df(session, query, print_query)
#      64     if print_query:
#      65         print(query)
# ---> 66     data=session.run(query).data()
#      67     df = pd.json_normalize(data)
#      68     return(df)
#
# ~/opt/anaconda3/envs/neo4j_build/lib/python3.7/site-packages/neo4j/work/simple.py in run(self, query, parameters, **kwparameters)
#     215
#     216         self._autoResult = Result(cx, hydrant, self._config.fetch_size, self._result_closed)
# --> 217         self._autoResult._run(query, parameters, self._config.database, self._config.default_access_mode, self._bookmarks, **kwparameters)
#     218
#     219         return self._autoResult
#
# ~/opt/anaconda3/envs/neo4j_build/lib/python3.7/site-packages/neo4j/work/result.py in _run(self, query, parameters, db, access_mode, bookmarks, **kwparameters)
#      99         self._pull()
#     100         self._connection.send_all()
# --> 101         self._attach()
#     102
#     103     def _pull(self):
#
# ~/opt/anaconda3/envs/neo4j_build/lib/python3.7/site-packages/neo4j/work/result.py in _attach(self)
#     200         if self._closed is False:
#     201             while self._attached is False:
# --> 202                 self._connection.fetch_message()
#     203
#     204     def _buffer_all(self):
#
# ~/opt/anaconda3/envs/neo4j_build/lib/python3.7/site-packages/neo4j/io/_bolt4x1.py in fetch_message(self)
#     351             log.debug("[#%04X]  S: FAILURE %r", self.local_port, summary_metadata)
#     352             try:
# --> 353                 response.on_failure(summary_metadata or {})
#     354             except (ServiceUnavailable, DatabaseUnavailable):
#     355                 if self.pool:
#
# ~/opt/anaconda3/envs/neo4j_build/lib/python3.7/site-packages/neo4j/io/_bolt4x1.py in on_failure(self, metadata)
#     550         if callable(handler):
#     551             handler()
# --> 552         raise Neo4jError.hydrate(**metadata)
#     553
#     554     def on_ignored(self, metadata=None):
#
# CypherSyntaxError: {code: Neo.ClientError.Statement.SyntaxError} {message: Variable `None` not defined (line 3, column 21 (offset: 74))
# "WHERE outcome.id in None"
#                      ^}

# %% [markdown]
# ### Traits vs traits -- looking for intermediates

# %%
ids = list(pd.read_csv("../other_text_files/potential_intem_traits.csv")['x'])



query = """
MATCH (exposure:Gwas)-[mr:MR_EVE_MR]->(outcome:Gwas)
WHERE outcome.id in {ids} 
AND  exposure.id  in {ids}
AND mr.pval < 1e-05
with mr, exposure, outcome
ORDER BY exposure.trait
RETURN exposure.id, exposure.trait, exposure.sample_size, exposure.sex, exposure.note,
toInteger(exposure.year) as year, exposure.author as author, exposure.consortium as consortium,
        outcome.id, outcome.sample_size, toInteger(outcome.ncase) as N_case, outcome.year, outcome.nsnp,
        mr.pval, mr.b, mr.se, mr.method, mr.moescore
        
""".format(ids = ids )

df = query_to_df(session, query, True)


df
# Out:
# MATCH (exposure:Gwas)-[mr:MR_EVE_MR]->(outcome:Gwas)
# WHERE outcome.id in ['ukb-d-M13_POLYARTHROPATHIES', 'met-a-558', 'met-a-682', 'met-a-427', 'met-a-500', 'ukb-b-14067', 'ukb-b-16677', 'ukb-b-1004', 'ukb-b-18436', 'ukb-b-4643', 'ukb-a-320', 'ukb-b-17422', 'prot-a-67', 'ukb-d-20117_2', 'prot-a-1154', 'prot-a-1411', 'ieu-a-298', 'prot-a-99', 'ukb-d-30630_irnt', 'ukb-d-30630_raw', 'prot-a-310', 'ukb-b-5716', 'ukb-a-30', 'ukb-b-1707', 'prot-a-216', 'prot-a-212', 'prot-a-674', 'met-a-362', 'ieu-a-974', 'met-a-656', 'prot-a-390', 'prot-a-392', 'prot-a-399', 'prot-a-408', 'ieu-a-1015', 'prot-a-426', 'prot-a-655', 'prot-a-735', 'prot-a-486', 'prot-a-488', 'prot-a-346', 'prot-a-354', 'prot-a-366', 'ukb-a-58', 'ukb-a-60', 'ukb-d-C_PRIMARY_LYMPHOID_HEMATOPOIETIC', 'prot-a-550', 'prot-a-643', 'prot-a-710', 'prot-a-532', 'ukb-d-1468_5', 'prot-a-412', 'ukb-b-2221', 'ukb-a-295', 'ieu-a-1096', 'prot-a-714', 'prot-a-381', 'ukb-a-34', 'prot-a-305', 'prot-a-322', 'prot-a-518', 'prot-a-521', 'ukb-d-6020_33', 'met-c-890', 'prot-a-608', 'prot-a-609', 'prot-a-500', 'ukb-b-16858', 'prot-a-197', 'prot-a-654', 'prot-a-706', 'ukb-b-4955', 'met-a-618', 'prot-a-831', 'prot-a-867', 'ukb-d-D17', 'ukb-a-528', 'ukb-d-H33', 'ukb-d-J45', 'ukb-b-3672', 'ukb-b-7352', 'ukb-b-11064', 'prot-a-2629', 'prot-a-2464', 'prot-a-836', 'prot-a-586', 'prot-a-2665', 'prot-a-2573', 'prot-a-982', 'ukb-d-IV_ENDOCRIN_NUTRIT', 'prot-a-892', 'prot-a-2071', 'prot-a-1707', 'prot-a-1835', 'prot-a-977', 'prot-a-2892', 'ukb-d-20406', 'ukb-a-373', 'ukb-b-6445', 'ukb-d-20500', 'prot-a-2891', 'ukb-a-426', 'ukb-b-10181', 'ukb-d-5012', 'ukb-b-2535', 'ukb-b-3666', 'prot-a-1148', '
#         outcome.id, outcome.sample_size, toInteger(outcome.ncase) as N_case, outcome.year, outcome.nsnp,
#         mr.pval, mr.b, mr.se, mr.method, mr.moescore
#                       exposure.id                           exposure.trait  \
# 0     ukb-d-M13_POLYARTHROPATHIES                       #Polyarthropathies
# 1     ukb-d-M13_POLYARTHROPATHIES                       #Polyarthropathies
# 2     ukb-d-M13_POLYARTHROPATHIES                       #Polyarthropathies
# 3     ukb-d-M13_POLYARTHROPATHIES                       #Polyarthropathies
# 4     ukb-d-M13_POLYARTHROPATHIES                       #Polyarthropathies
# ...                           ...                                      ...
# 4961                  prot-a-2575  rRNA methyltransferase 3, mitochondrial
# 4962                  prot-a-2575  rRNA methyltransferase 3, mitochondrial
# 4963                  prot-a-2575  rRNA methyltransferase 3, mitochondrial
# 4964                  prot-a-2575  rRNA methyltransferase 3, mitochondrial
# 4965                  prot-a-2575  rRNA methyltransferase 3, mitochondrial
#
#      exposure.sample_size       exposure.sex exposure.note  year     author  \
# 0                361194.0  Males and Females          None  2018  Neale lab
# 1                361194.0  Males and Females          None  2018  Neale lab
# 2                361194.0  Males and Females          None  2018  Neale lab
# 3                361194.0  Males and Females          None  2018  Neale lab
# 4                361194.0  Males and Females          None  2018  Neale lab
# ...                   ...                ...           ...   ...        ...
# 4961               3301.0  Males and Females          None  2018     Sun BB
# 4962               3301.0  Males and Females          None  2018     Sun BB
# 4963               3301.0  Males and Females          None  2018     Sun BB
# 4964               3301.0  Males and Females          None  2018     Sun BB
# 4965               3301.0  Males and Females          None  2018     Sun BB
#
#      consortium   outcome.id outcome.sample_size   N_case outcome.year  \
# 0          None   ukb-b-3672            463010.0  14326.0       2018.0
# 1          None    ukb-d-D17            361194.0   4314.0       2018.0
# 2          None   prot-a-714              3301.0      NaN       2018.0
# 3          None    ukb-d-J45            361194.0   1693.0       2018.0
# 4          None   ukb-b-6445            221697.0  18171.0       2018.0
# ...         ...          ...                 ...      ...          ...
# 4961       None  prot-a-2189              3301.0      NaN       2018.0
# 4962       None   prot-a-310              3301.0      NaN       2018.0
# 4963       None  prot-a-2820              3301.0      NaN       2018.0
# 4964       None  prot-a-2247              3301.0      NaN       2018.0
# 4965       None  prot-a-1317              3301.0      NaN       2018.0
#
#      outcome.nsnp       mr.pval      mr.b     mr.se mr.method  mr.moescore
# 0       9851867.0  1.086372e-12  0.353187  0.049611    FE IVW          1.0
# 1      11857594.0  2.784593e-10  0.204733  0.032444    FE IVW          1.0
# 2      10534735.0  7.432935e-10  5.031430  0.817243    FE IVW          1.0
# 3      10336532.0  2.094952e-11  0.270787  0.040421    FE IVW          1.0
# 4       9851867.0  1.599454e-09  1.150836  0.190725    FE IVW          1.0
# ...           ...           ...       ...       ...       ...          ...
# 4961   10534735.0  2.174772e-16  0.296702  0.036130    FE IVW          1.0
# 4962   10534735.0  1.030570e-10  0.244003  0.037757    FE IVW          1.0
# 4963   10534735.0  1.729263e-06 -0.052297  0.010935    FE IVW          1.0
# 4964   10534735.0  1.544343e-06 -0.101734  0.021171    FE IVW          1.0
# 4965   10534735.0  2.441953e-06  0.166903  0.035414    FE IVW          1.0
#
# [4966 rows x 18 columns]

# %%
df.to_csv("../query_results/bc_risk_factors_mr.tsv", sep="\t", index=False)

# %% [markdown]
# ### Correlation

# %%
# find which traits are highly correlated with UKB cancers

query = """
MATCH (trait:Gwas)-[gen_cor:GEN_COR]-(assoc_trait:Gwas)
where assoc_trait.id in ['ukb-a-519']
match (trait:Gwas)-[mr:MR_EVE_MR]->(assoc_trait:Gwas)
//where mr.pval < 1e-03
return distinct trait.trait, trait.id, gen_cor.rg, assoc_trait.trait, assoc_trait.id, mr.b, mr.pval
order by gen_cor.rg desc
"""
df = query_to_df(session, query)
df
# Out:
# MATCH (trait:Gwas)-[gen_cor:GEN_COR]-(assoc_trait:Gwas)
# where assoc_trait.id in ['ukb-a-519']
# match (trait:Gwas)-[mr:MR_EVE_MR]->(assoc_trait:Gwas)
# //where mr.pval < 1e-03
# return distinct trait.trait, trait.id, gen_cor.rg, assoc_trait.trait, assoc_trait.id, mr.b, mr.pval
# order by gen_cor.rg desc
#                                            trait.trait   trait.id  gen_cor.rg  \
# 0                      Number of self-reported cancers   ukb-a-21      0.8279
# 1                           Had other major operations  ukb-a-326      0.2660
# 2                                  Breastfed as a baby   ukb-a-33      0.2471
# 3                              Headaches for 3+ months  ukb-a-354      0.1980
# 4      Qualifications: NVQ or HND or HNC or equivalent  ukb-a-402      0.1885
# ..                                                 ...        ...         ...
# 260  Reason for glasses/contact lenses: For 'astigm...  ukb-a-422     -0.1279
# 261  Diagnoses - main ICD10: I21 Acute myocardial i...  ukb-a-533     -0.1304
# 262  Number of days/week of vigorous physical activ...  ukb-a-511     -0.1306
# 263  Mineral and other dietary supplements: None of...  ukb-a-493     -0.1405
# 264  Types of transport used (excluding work): Car/...  ukb-a-478     -0.1570
#
#                                      assoc_trait.trait assoc_trait.id  \
# 0    Diagnoses - main ICD10: C50 Malignant neoplasm...      ukb-a-519
# 1    Diagnoses - main ICD10: C50 Malignant neoplasm...      ukb-a-519
# 2    Diagnoses - main ICD10: C50 Malignant neoplasm...      ukb-a-519
# 3    Diagnoses - main ICD10: C50 Malignant neoplasm...      ukb-a-519
# 4    Diagnoses - main ICD10: C50 Malignant neoplasm...      ukb-a-519
# ..                                                 ...            ...
# 260  Diagnoses - main ICD10: C50 Malignant neoplasm...      ukb-a-519
# 261  Diagnoses - main ICD10: C50 Malignant neoplasm...      ukb-a-519
# 262  Diagnoses - main ICD10: C50 Malignant neoplasm...      ukb-a-519
# 263  Diagnoses - main ICD10: C50 Malignant neoplasm...      ukb-a-519
# 264  Diagnoses - main ICD10: C50 Malignant neoplasm...      ukb-a-519
#
#          mr.b       mr.pval
# 0    0.077594  1.850559e-02
# 1    0.026946  5.000000e-01
# 2   -0.012162  5.060810e-01
# 3   -0.017729  3.182665e-29
# 4    0.026366  5.000000e-01
# ..        ...           ...
# 260 -0.077385  5.000000e-01
# 261 -0.057651  5.647018e-01
# 262 -0.006864  3.821609e-02
# 263 -0.014608  6.539805e-01
# 264 -0.033081  5.000000e-01
#
# [265 rows x 7 columns]
