# %%
import pandas as pd
import json
from environs import Env
from graph_functions import query_to_df,start_graph_session,start_graph_session_crashdown
from IPython.display import Image


env = Env()
#session = start_graph_session(env) 
session = start_graph_session_crashdown(env)
# Out:
# 14196

# %% [markdown]
# In this norebook:
# - explore trastusumab as positive control for graph connectivity
# - explore taximofen as positive control

# %% [markdown]
# ## Basic test1: drugs to disease

# %%
query="""
match (drug:Drug)
where toLower(drug.label) contains "trastuzumab"
return drug.label, drug.id
"""
df= query_to_df(session, query)
df
# Out:
# match (drug:Drug)
# where toLower(drug.label) contains "trastuzumab"
# return drug.label, drug.id
#                drug.label drug.id
# 0   TRASTUZUMAB EMTANSINE    None
# 1  TRASTUZUMAB DERUXTECAN    None
# 2             TRASTUZUMAB    None

# %%
# drugs to disease
query="""
match (drug:Drug)-[:OPENTARGETS_DRUG_TO_DISEASE]->(disease:Disease)
where toLower(drug.label) contains "trastuzumab"
return drug.label, drug.id, disease.label
"""
df= query_to_df(session, query)
df
# Out:
# match (drug:Drug)-[:OPENTARGETS_DRUG_TO_DISEASE]->(disease:Disease)
# where toLower(drug.label) contains "trastuzumab"
# return drug.label, drug.id, disease.label
#                drug.label drug.id       disease.label
# 0   TRASTUZUMAB EMTANSINE    None    breast carcinoma
# 1   TRASTUZUMAB EMTANSINE    None  neoplasm (disease)
# 2   TRASTUZUMAB EMTANSINE    None       breast cancer
# 3  TRASTUZUMAB DERUXTECAN    None       breast cancer
# 4             TRASTUZUMAB    None    breast carcinoma

# %%
# drug to gene to protein to pathway
query="""
match (drug:Drug)-[:OPENTARGETS_DRUG_TO_TARGET]->(gene:Gene)-[]->(p:Protein)-[]->(path:Pathway)
where toLower(drug.label) contains "trastuzumab"
return drug.label,  gene.name as GeneTarget, 
        collect(distinct p.name) as proteinProducts, collect(path.name) as pathways
order by drug.label
"""
df= query_to_df(session, query)
df
# Out:
# match (drug:Drug)-[:OPENTARGETS_DRUG_TO_TARGET]->(gene:Gene)-[]->(p:Protein)-[]->(path:Pathway)
# where toLower(drug.label) contains "trastuzumab"
# return drug.label,  gene.name as GeneTarget,
#         collect(distinct p.name) as proteinProducts, collect(path.name) as pathways
# order by drug.label
#                 drug.label GeneTarget proteinProducts  \
# 0              TRASTUZUMAB      ERBB2        [P04626]
# 1   TRASTUZUMAB DERUXTECAN      ERBB2        [P04626]
# 2   TRASTUZUMAB DERUXTECAN       TOP1        [P11387]
# 3    TRASTUZUMAB EMTANSINE     TUBB4B        [P68371]
# 4    TRASTUZUMAB EMTANSINE       TUBB        [P07437]
# 5    TRASTUZUMAB EMTANSINE     TUBB4A        [P04350]
# 6    TRASTUZUMAB EMTANSINE     TUBB2A        [Q13885]
# 7    TRASTUZUMAB EMTANSINE      TUBB3        [Q13509]
# 8    TRASTUZUMAB EMTANSINE      TUBB1        [Q9H4B7]
# 9    TRASTUZUMAB EMTANSINE     TUBB2B        [Q9BVA1]
# 10   TRASTUZUMAB EMTANSINE      TUBB6        [Q9BUF5]
# 11   TRASTUZUMAB EMTANSINE      ERBB2        [P04626]
#
#                                              pathways
# 0   [Axon guidance, Constitutive Signaling by Aber...
# 1   [Axon guidance, Constitutive Signaling by Aber...
# 2   [Metabolism of proteins, Post-translational pr...
# 3   [AURKA Activation by TPX2, Activation of AMPK ...
# 4   [AURKA Activation by TPX2, Anchoring of the ba...
# 5   [AURKA Activation by TPX2, Activation of AMPK ...
# 6   [Activation of AMPK downstream of NMDARs, Acti...
# 7   [Activation of AMPK downstream of NMDARs, Acti...
# 8   [Activation of AMPK downstream of NMDARs, Acti...
# 9   [Activation of AMPK downstream of NMDARs, Acti...
# 10  [Activation of AMPK downstream of NMDARs, Acti...
# 11  [Axon guidance, Constitutive Signaling by Aber...

# %%
query="""
match (drug:Drug)-[r1:OPENTARGETS_DRUG_TO_TARGET]->(gene:Gene)-[r2]->(p:Protein)
where toLower(drug.label) contains "trastuzumab"
return drug, gene, p,  r1,r2
"""
# image

# %%
Image(filename = "figures/herceptin_genes.png", width = 800)

# %%
# drug to gene (lit term) to other lit term; drug to disease 

query="""
match (drug:Drug)-[r1:OPENTARGETS_DRUG_TO_TARGET]->(gene:Gene)<-[:TERM_TO_GENE]-(l1:LiteratureTerm)-[]-(lt:LiteratureTriple)-[]-(l2:LiteratureTerm)
where toLower(drug.label) contains "trastuzumab"
match (drug)-[r4]->(disease:Disease)
set disease.name = disease.label
return drug.label, gene.name, disease.name, 
        l1.name as term1, lt.predicate as pred1, l2.name as term2 
"""
df_complex= query_to_df(session, query)
df_complex
# Out:
# match (drug:Drug)-[r1:OPENTARGETS_DRUG_TO_TARGET]->(gene:Gene)<-[:TERM_TO_GENE]-(l1:LiteratureTerm)-[]-(lt:LiteratureTriple)-[]-(l2:LiteratureTerm)
# where toLower(drug.label) contains "trastuzumab"
# match (drug)-[r4]->(disease:Disease)
# set disease.name = disease.label
# return drug.label, gene.name, disease.name,
#         l1.name as term1, lt.predicate as pred1, l2.name as term2
#                   drug.label gene.name        disease.name  term1  \
# 0      TRASTUZUMAB EMTANSINE     ERBB2    breast carcinoma  ERBB2
# 1      TRASTUZUMAB EMTANSINE     ERBB2  neoplasm (disease)  ERBB2
# 2      TRASTUZUMAB EMTANSINE     ERBB2       breast cancer  ERBB2
# 3      TRASTUZUMAB EMTANSINE     ERBB2    breast carcinoma  ERBB2
# 4      TRASTUZUMAB EMTANSINE     ERBB2  neoplasm (disease)  ERBB2
# ...                      ...       ...                 ...    ...
# 33158            TRASTUZUMAB     ERBB2    breast carcinoma  ERBB2
# 33159            TRASTUZUMAB     ERBB2    breast carcinoma  ERBB2
# 33160            TRASTUZUMAB     ERBB2    breast carcinoma  ERBB2
# 33161            TRASTUZUMAB     ERBB2    breast carcinoma  ERBB2
# 33162            TRASTUZUMAB     ERBB2    breast carcinoma  ERBB2
#
#                 pred1                          term2
# 0      INTERACTS_WITH                           BRAF
# 1      INTERACTS_WITH                           BRAF
# 2      INTERACTS_WITH                           BRAF
# 3      INTERACTS_WITH                      BRAF gene
# 4      INTERACTS_WITH                      BRAF gene
# ...               ...                            ...
# 33158  INTERACTS_WITH                           AKT1
# 33159  INTERACTS_WITH  Proto-Oncogene Proteins c-akt
# 33160  INTERACTS_WITH         Antibodies, Bispecific
# 33161  INTERACTS_WITH                          Agent
# 33162  INTERACTS_WITH                      Herceptin
#
# [33163 rows x 6 columns]

# %%
# need to explore the table above!

# %% [markdown]
# ## Basic test2: drugs to disease

# %%
query="""
match (drug:Drug)
where toLower(drug.label) contains "tamoxifen"
return drug.label, drug.chembl_uri
"""
df= query_to_df(session, query)
df
# Out:
# match (drug:Drug)
# where toLower(drug.label) contains "tamoxifen"
# return drug.label, drug.chembl_uri
#   drug.label                                  drug.chembl_uri
# 0  TAMOXIFEN  http://identifiers.org/chembl.compound/CHEMBL83

# %%
# drugs to disease
query="""
match (drug:Drug)-[:OPENTARGETS_DRUG_TO_DISEASE]->(disease:Disease)
where drug.chembl_uri =  'http://identifiers.org/chembl.compound/CHEMBL83'
return drug.label, drug.chembl_uri, disease.label
"""
df= query_to_df(session, query)
df
# Out:
# match (drug:Drug)-[:OPENTARGETS_DRUG_TO_DISEASE]->(disease:Disease)
# where drug.chembl_uri =  'http://identifiers.org/chembl.compound/CHEMBL83'
# return drug.label, drug.chembl_uri, disease.label
#   drug.label                                  drug.chembl_uri  disease.label
# 0  TAMOXIFEN  http://identifiers.org/chembl.compound/CHEMBL83  breast cancer

# %%
# drug to gene to protein to pathway
query="""
match (drug:Drug)-[:OPENTARGETS_DRUG_TO_TARGET]->(gene:Gene)-[]->(p:Protein)-[]->(path:Pathway)
where drug.chembl_uri =  'http://identifiers.org/chembl.compound/CHEMBL83'
return drug.label,  gene.name as GeneTarget, 
        collect(distinct p.name) as proteinProducts, collect(path.name) as pathways
order by drug.label
"""
df= query_to_df(session, query)
df
# Out:
# match (drug:Drug)-[:OPENTARGETS_DRUG_TO_TARGET]->(gene:Gene)-[]->(p:Protein)-[]->(path:Pathway)
# where drug.chembl_uri =  'http://identifiers.org/chembl.compound/CHEMBL83'
# return drug.label,  gene.name as GeneTarget,
#         collect(distinct p.name) as proteinProducts, collect(path.name) as pathways
# order by drug.label
#   drug.label GeneTarget proteinProducts  \
# 0  TAMOXIFEN       ESR1        [P03372]
#
#                                             pathways
# 0  [Estrogen-dependent gene expression, Extra-nuc...

# %%
query="""
match(p:Pathway)
where p.name in {}
return p
""".format(df['pathways'][0])
df= query_to_df(session, query)
df
# Out:
# match(p:Pathway)
# where p.name in ['Estrogen-dependent gene expression', 'Extra-nuclear estrogen signaling', 'Signaling by Receptor Tyrosine Kinases', 'Signaling by Nuclear Receptors', 'Intracellular signaling by second messengers', 'Regulation of RUNX2 expression and activity', 'RUNX1 regulates transcription of genes involved in WNT signaling', 'ESR-mediated signaling', 'RUNX1 regulates estrogen receptor mediated transcription', 'Transcriptional regulation by RUNX1', 'Transcriptional regulation by RUNX2', 'TFAP2 (AP-2) family regulates transcription of growth factors and their receptors', 'Transcriptional regulation by the AP-2 (TFAP2) family of transcription factors', 'Gene expression (Transcription)', 'RNA Polymerase II Transcription', 'PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling', 'Post-translational protein modification', 'Ovarian tumor domain proteases', 'Deubiquitination', 'Diseases of signal transduction by growth factor receptors and second messengers', 'SUMOylation of intracellular receptors', 'Metabolism of proteins', 'Nuclear Receptor transcription pathway', 'SUMO E3 ligases SUMOylate target proteins', 'SUMOylation', 'Constitutive Signaling by Aberrant PI3K in Cancer', 'PI3K/AKT Signaling in Cancer', 'Generic Transcription Pathway', 'Negative regulation of the PI3K/AKT network', 'Disease', 'Signal Transduction', 'PIP3 activates AKT signaling', 'Nuclear signaling by ERBB4', 'Signaling by ERBB4']
# return p
#                                               p._name  \
# 0   Constitutive Signaling by Aberrant PI3K in Cancer
# 1                                    Deubiquitination
# 2                                             Disease
# 3   Diseases of signal transduction by growth fact...
# 4                              ESR-mediated signaling
# 5                  Estrogen-dependent gene expression
# 6                    Extra-nuclear estrogen signaling
# 7                     Gene expression (Transcription)
# 8                       Generic Transcription Pathway
# 9        Intracellular signaling by second messengers
# 10                             Metabolism of proteins
# 11        Negative regulation of the PI3K/AKT network
# 12             Nuclear Receptor transcription pathway
# 13                         Nuclear signaling by ERBB4
# 14                     Ovarian tumor domain proteases
# 15                       PI3K/AKT Signaling in Cancer
# 16    PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling
# 17                       PIP3 activates AKT signaling
# 18            Post-translational protein modification
# 19                    RNA Polymerase II Transcription
# 20  RUNX1 regulates estrogen receptor mediated tra...
# 21  RUNX1 regulates transcription of genes involve...
# 22        Regulation of RUNX2 expression and activity
# 23          SUMO E3 ligases SUMOylate target proteins
# 24                                        SUMOylation
# 25             SUMOylation of intracellular receptors
# 26                                Signal Transduction
# 27                                 Signaling by ERBB4
# 28                     Signaling by Nuclear Receptors
# 29             Signaling by Receptor Tyrosine Kinases
# 30  TFAP2 (AP-2) family regulates transcription of...
# 31                Transcriptional regulation by RUNX1
# 32                Transcriptional regulation by RUNX2
# 33  Transcriptional regulation by the AP-2 (TFAP2)...
#
#                                                p.name              p._source  \
# 0   Constitutive Signaling by Aberrant PI3K in Cancer  [Reactome-2020-10-13]
# 1                                    Deubiquitination  [Reactome-2020-10-13]
# 2                                             Disease  [Reactome-2020-10-13]
# 3   Diseases of signal transduction by growth fact...  [Reactome-2020-10-13]
# 4                              ESR-mediated signaling  [Reactome-2020-10-13]
# 5                  Estrogen-dependent gene expression  [Reactome-2020-10-13]
# 6                    Extra-nuclear estrogen signaling  [Reactome-2020-10-13]
# 7                     Gene expression (Transcription)  [Reactome-2020-10-13]
# 8                       Generic Transcription Pathway  [Reactome-2020-10-13]
# 9        Intracellular signaling by second messengers  [Reactome-2020-10-13]
# 10                             Metabolism of proteins  [Reactome-2020-10-13]
# 11        Negative regulation of the PI3K/AKT network  [Reactome-2020-10-13]
# 12             Nuclear Receptor transcription pathway  [Reactome-2020-10-13]
# 13                         Nuclear signaling by ERBB4  [Reactome-2020-10-13]
# 14                     Ovarian tumor domain proteases  [Reactome-2020-10-13]
# 15                       PI3K/AKT Signaling in Cancer  [Reactome-2020-10-13]
# 16    PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling  [Reactome-2020-10-13]
# 17                       PIP3 activates AKT signaling  [Reactome-2020-10-13]
# 18            Post-translational protein modification  [Reactome-2020-10-13]
# 19                    RNA Polymerase II Transcription  [Reactome-2020-10-13]
# 20  RUNX1 regulates estrogen receptor mediated tra...  [Reactome-2020-10-13]
# 21  RUNX1 regulates transcription of genes involve...  [Reactome-2020-10-13]
# 22        Regulation of RUNX2 expression and activity  [Reactome-2020-10-13]
# 23          SUMO E3 ligases SUMOylate target proteins  [Reactome-2020-10-13]
# 24                                        SUMOylation  [Reactome-2020-10-13]
# 25             SUMOylation of intracellular receptors  [Reactome-2020-10-13]
# 26                                Signal Transduction  [Reactome-2020-10-13]
# 27                                 Signaling by ERBB4  [Reactome-2020-10-13]
# 28                     Signaling by Nuclear Receptors  [Reactome-2020-10-13]
# 29             Signaling by Receptor Tyrosine Kinases  [Reactome-2020-10-13]
# 30  TFAP2 (AP-2) family regulates transcription of...  [Reactome-2020-10-13]
# 31                Transcriptional regulation by RUNX1  [Reactome-2020-10-13]
# 32                Transcriptional regulation by RUNX2  [Reactome-2020-10-13]
# 33  Transcriptional regulation by the AP-2 (TFAP2)...  [Reactome-2020-10-13]
#
#              p.id          p._id  \
# 0   R-HSA-2219530  R-HSA-2219530
# 1   R-HSA-5688426  R-HSA-5688426
# 2   R-HSA-1643685  R-HSA-1643685
# 3   R-HSA-5663202  R-HSA-5663202
# 4   R-HSA-8939211  R-HSA-8939211
# 5   R-HSA-9018519  R-HSA-9018519
# 6   R-HSA-9009391  R-HSA-9009391
# 7     R-HSA-74160    R-HSA-74160
# 8    R-HSA-212436   R-HSA-212436
# 9   R-HSA-9006925  R-HSA-9006925
# 10   R-HSA-392499   R-HSA-392499
# 11   R-HSA-199418   R-HSA-199418
# 12   R-HSA-383280   R-HSA-383280
# 13  R-HSA-1251985  R-HSA-1251985
# 14  R-HSA-5689896  R-HSA-5689896
# 15  R-HSA-2219528  R-HSA-2219528
# 16  R-HSA-6811558  R-HSA-6811558
# 17  R-HSA-1257604  R-HSA-1257604
# 18   R-HSA-597592   R-HSA-597592
# 19    R-HSA-73857    R-HSA-73857
# 20  R-HSA-8931987  R-HSA-8931987
# 21  R-HSA-8939256  R-HSA-8939256
# 22  R-HSA-8939902  R-HSA-8939902
# 23  R-HSA-3108232  R-HSA-3108232
# 24  R-HSA-2990846  R-HSA-2990846
# 25  R-HSA-4090294  R-HSA-4090294
# 26   R-HSA-162582   R-HSA-162582
# 27  R-HSA-1236394  R-HSA-1236394
# 28  R-HSA-9006931  R-HSA-9006931
# 29  R-HSA-9006934  R-HSA-9006934
# 30  R-HSA-8866910  R-HSA-8866910
# 31  R-HSA-8878171  R-HSA-8878171
# 32  R-HSA-8878166  R-HSA-8878166
# 33  R-HSA-8864260  R-HSA-8864260
#
#                                                 p.url
# 0   https://reactome.org/PathwayBrowser/#/R-HSA-22...
# 1   https://reactome.org/PathwayBrowser/#/R-HSA-56...
# 2   https://reactome.org/PathwayBrowser/#/R-HSA-16...
# 3   https://reactome.org/PathwayBrowser/#/R-HSA-56...
# 4   https://reactome.org/PathwayBrowser/#/R-HSA-89...
# 5   https://reactome.org/PathwayBrowser/#/R-HSA-90...
# 6   https://reactome.org/PathwayBrowser/#/R-HSA-90...
# 7   https://reactome.org/PathwayBrowser/#/R-HSA-74160
# 8   https://reactome.org/PathwayBrowser/#/R-HSA-21...
# 9   https://reactome.org/PathwayBrowser/#/R-HSA-90...
# 10  https://reactome.org/PathwayBrowser/#/R-HSA-39...
# 11  https://reactome.org/PathwayBrowser/#/R-HSA-19...
# 12  https://reactome.org/PathwayBrowser/#/R-HSA-38...
# 13  https://reactome.org/PathwayBrowser/#/R-HSA-12...
# 14  https://reactome.org/PathwayBrowser/#/R-HSA-56...
# 15  https://reactome.org/PathwayBrowser/#/R-HSA-22...
# 16  https://reactome.org/PathwayBrowser/#/R-HSA-68...
# 17  https://reactome.org/PathwayBrowser/#/R-HSA-12...
# 18  https://reactome.org/PathwayBrowser/#/R-HSA-59...
# 19  https://reactome.org/PathwayBrowser/#/R-HSA-73857
# 20  https://reactome.org/PathwayBrowser/#/R-HSA-89...
# 21  https://reactome.org/PathwayBrowser/#/R-HSA-89...
# 22  https://reactome.org/PathwayBrowser/#/R-HSA-89...
# 23  https://reactome.org/PathwayBrowser/#/R-HSA-31...
# 24  https://reactome.org/PathwayBrowser/#/R-HSA-29...
# 25  https://reactome.org/PathwayBrowser/#/R-HSA-40...
# 26  https://reactome.org/PathwayBrowser/#/R-HSA-16...
# 27  https://reactome.org/PathwayBrowser/#/R-HSA-12...
# 28  https://reactome.org/PathwayBrowser/#/R-HSA-90...
# 29  https://reactome.org/PathwayBrowser/#/R-HSA-90...
# 30  https://reactome.org/PathwayBrowser/#/R-HSA-88...
# 31  https://reactome.org/PathwayBrowser/#/R-HSA-88...
# 32  https://reactome.org/PathwayBrowser/#/R-HSA-88...
# 33  https://reactome.org/PathwayBrowser/#/R-HSA-88...

# %% [markdown]
# # Basic test 3: mechanistic pathways check
#
# https://www.genome.jp/kegg-bin/show_pathway?hsa05224

# %%
gene_list1 = ['IGF1', 'IFG1R', 'PIK3CA', 'PTEN', 'AKT1', 'MTOR', 'RPS6KB1']

# %%
#query= """
#MATCH (gene:Gene)-[gene_to_protein:GENE_TO_PROTEIN]->(protein:Protein)
#WHERE gene.name in {}
#RETURN gene, protein
#""".format(glist=gene_list1)
Image(filename = "figures/PC_test3_igf_path_bad.png")

# %%
query= """
MATCH (gene1:Gene)-[gene_to_protein1:GENE_TO_PROTEIN]->(protein1:Protein)-[string:STRING_INTERACT_WITH]->(protein2:Protein)<-[gene_to_protein2:GENE_TO_PROTEIN]-(gene2:Gene)
WHERE gene1.name in {glist} and gene2.name in {glist}
RETURN gene1.name,  string.score, gene2.name
order by string.score desc
""".format(glist=gene_list1)
df= query_to_df(session, query)
df
# Out:
# MATCH (gene1:Gene)-[gene_to_protein1:GENE_TO_PROTEIN]->(protein1:Protein)-[string:STRING_INTERACT_WITH]->(protein2:Protein)<-[gene_to_protein2:GENE_TO_PROTEIN]-(gene2:Gene)
# WHERE gene1.name in ['IGF1', 'IFG1R', 'PIK3CA', 'PTEN', 'AKT1', 'MTOR', 'RPS6KB1'] and gene2.name in ['IGF1', 'IFG1R', 'PIK3CA', 'PTEN', 'AKT1', 'MTOR', 'RPS6KB1']
# RETURN gene1.name,  string.score, gene2.name
# order by string.score desc
#    gene1.name  string.score gene2.name
# 0        MTOR         999.0    RPS6KB1
# 1        AKT1         999.0       MTOR
# 2     RPS6KB1         999.0       MTOR
# 3        MTOR         999.0       AKT1
# 4      PIK3CA         998.0       AKT1
# 5        AKT1         998.0     PIK3CA
# 6        PTEN         996.0     PIK3CA
# 7      PIK3CA         996.0       PTEN
# 8        AKT1         992.0    RPS6KB1
# 9     RPS6KB1         992.0       AKT1
# 10       PTEN         990.0       AKT1
# 11       AKT1         990.0       PTEN
# 12    RPS6KB1         982.0     PIK3CA
# 13     PIK3CA         982.0    RPS6KB1
# 14       IGF1         969.0    RPS6KB1
# 15    RPS6KB1         969.0       IGF1
# 16       AKT1         960.0       IGF1
# 17       IGF1         960.0       AKT1
# 18       PTEN         951.0       MTOR
# 19       MTOR         951.0       PTEN
# 20       IGF1         947.0     PIK3CA
# 21     PIK3CA         947.0       IGF1
# 22       MTOR         944.0     PIK3CA
# 23     PIK3CA         944.0       MTOR
# 24       PTEN         921.0    RPS6KB1
# 25    RPS6KB1         921.0       PTEN
# 26       MTOR         748.0       IGF1
# 27       IGF1         748.0       MTOR

# %%
#query= """
#MATCH (gene1:Gene)-[gene_to_protein1:GENE_TO_PROTEIN]->(protein1:Protein)-[string:STRING_INTERACT_WITH]->(protein2:Protein)<-[gene_to_protein2:GENE_TO_PROTEIN]-(gene2:Gene)
#WHERE gene1.name in {glist} and gene2.name in {glist}
#and string.score in  [999.0, 998.0, 996.0]
#return gene1,gene_to_protein1,  protein1, string
#""".format(glist=gene_list1)
Image(filename = "figures/PC_test3_igf_path_good.png")

# %%
gene_list2 = ['EGF', 'EGFR', 'ERBB2', 'SHC1', 'GRB2', 'SOS1',' KRAS', 'RAF1', 'BFAR', 'MAP2K7', 'MAPK3', 'MAPK1']

# %%
query= """
MATCH (gene1:Gene)-[gene_to_protein1:GENE_TO_PROTEIN]->(protein1:Protein)-[string:STRING_INTERACT_WITH]->(protein2:Protein)<-[gene_to_protein2:GENE_TO_PROTEIN]-(gene2:Gene)
WHERE gene1.name in {glist} and gene2.name in {glist}
RETURN gene1.name,  string.score, gene2.name
order by string.score desc
""".format(glist=gene_list2)
df= query_to_df(session, query)
df
# Out:
# MATCH (gene1:Gene)-[gene_to_protein1:GENE_TO_PROTEIN]->(protein1:Protein)-[string:STRING_INTERACT_WITH]->(protein2:Protein)<-[gene_to_protein2:GENE_TO_PROTEIN]-(gene2:Gene)
# WHERE gene1.name in ['EGF', 'EGFR', 'ERBB2', 'SHC1', 'GRB2', 'SOS1', ' KRAS', 'RAF1', 'BFAR', 'MAP2K7', 'MAPK3', 'MAPK1'] and gene2.name in ['EGF', 'EGFR', 'ERBB2', 'SHC1', 'GRB2', 'SOS1', ' KRAS', 'RAF1', 'BFAR', 'MAP2K7', 'MAPK3', 'MAPK1']
# RETURN gene1.name,  string.score, gene2.name
# order by string.score desc
#    gene1.name  string.score gene2.name
# 0        EGFR         999.0        EGF
# 1        SHC1         999.0       GRB2
# 2        SOS1         999.0       GRB2
# 3        EGFR         999.0       GRB2
# 4        GRB2         999.0       SHC1
# ..        ...           ...        ...
# 57       RAF1         796.0        EGF
# 58       GRB2         788.0       RAF1
# 59       RAF1         788.0       GRB2
# 60        EGF         783.0     MAP2K7
# 61     MAP2K7         783.0        EGF
#
# [62 rows x 3 columns]

# %%
query= """
MATCH (gene1:Gene)-[gene_to_protein1:GENE_TO_PROTEIN]->(protein1:Protein)-[string:STRING_INTERACT_WITH]->(protein2:Protein)<-[gene_to_protein2:GENE_TO_PROTEIN]-(gene2:Gene)
WHERE gene1.name in {glist} and gene2.name in {glist}
and string.score in  [999.0, 998.0, 996.0]
return gene1,gene_to_protein1,  protein1, string
""".format(glist=gene_list1)

Image(filename = "figures/PC_test3_her2_path_incomplete.png")
