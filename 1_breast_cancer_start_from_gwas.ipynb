# %%
import pandas as pd
import json
from environs import Env
from graph_functions import query_to_df,start_graph_session, start_graph_session_crashdown
from IPython.display import Image


env = Env()
session = start_graph_session(env) 
#session = start_graph_session_crashdown(env)
# Out:
# 37687

# %% [markdown]
# #### In this notebook:
#
# - Review all available breast cancer GWAS
# - Explore GWAS -> Pathways
#     - comparison between full/ER+/ER-
# - Explore GWAS -> Tissue
#     - gwas significant genes that are also expressed in breast tissue > 1 TPM
#     - 98/167 genes from 3 breast cancer GWAS are expressed in Breast tissue
#
#
# - MR

# %% [markdown]
# ## Get GWAS with available full summary data

# %%
query="""
MATCH (gwas:Gwas) -[gwas_to_variant:GWAS_TO_VARIANT]->(variant:Variant)
where toLower(gwas.trait) contains "breast"
and not(toLower(gwas.trait) contains "baby") and not(toLower(gwas.trait) contains "mother")
return distinct gwas.trait, gwas.id, gwas_to_variant.samplesize as SampleSize,
toInteger(gwas.ncase) as N_case, toInteger(gwas.ncontrol) as N_control, gwas.author, 
count(gwas_to_variant.pval) as signifSNPs
order by gwas_to_variant.samplesize desc
"""
df = query_to_df(session, query)
all_bc_gwas = list(df['gwas.id'])
df

# We are going to focus on 1126, 1127, 1128 for our main exploration
# Out:
# MATCH (gwas:Gwas) -[gwas_to_variant:GWAS_TO_VARIANT]->(variant:Variant)
# where toLower(gwas.trait) contains "breast"
# and not(toLower(gwas.trait) contains "baby") and not(toLower(gwas.trait) contains "mother")
# return distinct gwas.trait, gwas.id, gwas_to_variant.samplesize as SampleSize,
# toInteger(gwas.ncase) as N_case, toInteger(gwas.ncontrol) as N_control, gwas.author,
# count(gwas_to_variant.pval) as signifSNPs
# order by gwas_to_variant.samplesize desc
#                                            gwas.trait     gwas.id  SampleSize  \
# 0   Diagnoses - main ICD10: C50 Malignant neoplasm...   ukb-a-519      337199
# 1           Cancer code  self-reported: breast cancer    ukb-a-55      337159
# 2   Breast cancer (Combined Oncoarray; iCOGS; GWAS...  ieu-a-1126      228951
# 3   ER+ Breast cancer (Combined Oncoarray; iCOGS; ...  ieu-a-1127      175475
# 4   ER- Breast cancer (Combined Oncoarray; iCOGS; ...  ieu-a-1128      127442
# 5                           Breast cancer (Oncoarray)  ieu-a-1129      106776
# 6                               Breast cancer (iCOGS)  ieu-a-1130       89677
# 7                       ER+ Breast cancer (Oncoarray)  ieu-a-1132       83691
# 8                           ER+ Breast cancer (iCOGS)  ieu-a-1133       69970
# 9                       ER- Breast cancer (Oncoarray)  ieu-a-1135       55149
# 10                          ER- Breast cancer (iCOGS)  ieu-a-1136       50225
# 11                               Breast cancer (GWAS)  ieu-a-1131       32498
# 12                           ER- Breast cancer (GWAS)  ieu-a-1137       22068
# 13                           ER+ Breast cancer (GWAS)  ieu-a-1134       21814
#
#     N_case  N_control    gwas.author  signifSNPs
# 0     5510     331689          Neale           7
# 1     7480     329679          Neale          17
# 2   122977     105974  Michailidou K         141
# 3    69501     105974  Michailidou K         107
# 4    21468     105974  Michailidou K          37
# 5    61282      45494  Michailidou K          60
# 6    46785      42892  Michailidou K          47
# 7    38197      45494  Michailidou K          58
# 8    27078      42892  Michailidou K          41
# 9     9655      45494  Michailidou K          13
# 10    7333      42892  Michailidou K           6
# 11   14910      17588  Michailidou K          17
# 12    4480      17588  Michailidou K           2
# 13    4226      17588  Michailidou K           8

# %%
# get unique genes from all GWAS
query="""
MATCH (gwas:Gwas) -[gwas_to_variant:GWAS_TO_VARIANT]->(variant:Variant)-[variant_to_gene:VARIANT_TO_GENE]-> (gene:Gene)
WHERE gwas.id in {}
return distinct gene.name
order by gene.name

""".format(['ieu-a-1126', 'ieu-a-1127', 'ieu-a-1128'])
df = query_to_df(session, query)
df.shape
# Out:
# MATCH (gwas:Gwas) -[gwas_to_variant:GWAS_TO_VARIANT]->(variant:Variant)-[variant_to_gene:VARIANT_TO_GENE]-> (gene:Gene)
# WHERE gwas.id in ['ieu-a-1126', 'ieu-a-1127', 'ieu-a-1128']
# return distinct gene.name
# order by gene.name
# (167, 1)

# %% [markdown]
# ## Explore gwas->variant->gene->protein->pathway

# %%
# for major GWAS

def get_gwas_to_pathway(GWAS_ID):
    query = """
    MATCH (gwas:Gwas) -[gwas_to_variant:GWAS_TO_VARIANT]->(variant:Variant)-[variant_to_gene:VARIANT_TO_GENE]-> (gene:Gene)-[gene_to_protein:GENE_TO_PROTEIN]->(protein:Protein) -[protein_in_pathway:PROTEIN_IN_PATHWAY]->(pathway:Pathway) 
    WHERE gwas.id = '{gwas_id}' AND gwas_to_variant.pval < 1e-08 
    AND gene.name is not null 
    RETURN gwas.id, gwas_to_variant.beta, gwas_to_variant.pval, gwas_to_variant.samplesize as sampleSize,
           variant.name, gene.name, protein.uniprot_id, 
           collect (pathway.name) as Pathways, count (pathway.name) as N_pathways 
    ORDER BY gwas_to_variant.pval
    """.format(gwas_id=GWAS_ID)

    df = query_to_df(session, query)
    return df

bc_all_gwas_to_path = get_gwas_to_pathway(GWAS_ID = 'ieu-a-1126')
print(bc_all_gwas_to_path.shape[0])
bc_er_pos_gwas_to_path = get_gwas_to_pathway(GWAS_ID = 'ieu-a-1127')
print(bc_er_pos_gwas_to_path.shape[0])
bc_er_neg_gwas_to_path = get_gwas_to_pathway(GWAS_ID = 'ieu-a-1128')
print(bc_er_neg_gwas_to_path.shape[0])
# Out:
#     MATCH (gwas:Gwas) -[gwas_to_variant:GWAS_TO_VARIANT]->(variant:Variant)-[variant_to_gene:VARIANT_TO_GENE]-> (gene:Gene)-[gene_to_protein:GENE_TO_PROTEIN]->(protein:Protein) -[protein_in_pathway:PROTEIN_IN_PATHWAY]->(pathway:Pathway)
#     WHERE gwas.id = 'ieu-a-1126' AND gwas_to_variant.pval < 1e-08
#     AND gene.name is not null
#     RETURN gwas.id, gwas_to_variant.beta, gwas_to_variant.pval, gwas_to_variant.samplesize as sampleSize,
#            variant.name, gene.name, protein.uniprot_id,
#            collect (pathway.name) as Pathways, count (pathway.name) as N_pathways
#     ORDER BY gwas_to_variant.pval
#
# 53
#
#     MATCH (gwas:Gwas) -[gwas_to_variant:GWAS_TO_VARIANT]->(variant:Variant)-[variant_to_gene:VARIANT_TO_GENE]-> (gene:Gene)-[gene_to_protein:GENE_TO_PROTEIN]->(protein:Protein) -[protein_in_pathway:PROTEIN_IN_PATHWAY]->(pathway:Pathway)
#     WHERE gwas.id = 'ieu-a-1127' AND gwas_to_variant.pval < 1e-08
#     AND gene.name is not null
#     RETURN gwas.id, gwas_to_variant.beta, gwas_to_variant.pval, gwas_to_variant.samplesize as sampleSize,
#            variant.name, gene.name, protein.uniprot_id,
#            collect (pathway.name) as Pathways, count (pathway.name) as N_pathways
#     ORDER BY gwas_to_variant.pval
#
# 42
#
#     MATCH (gwas:Gwas) -[gwas_to_variant:GWAS_TO_VARIANT]->(variant:Variant)-[variant_to_gene:VARIANT_TO_GENE]-> (gene:Gene)-[gene_to_protein:GENE_TO_PROTEIN]->(protein:Protein) -[protein_in_pathway:PROTEIN_IN_PATHWAY]->(pathway:Pathway)
#     WHERE gwas.id = 'ieu-a-1128' AND gwas_to_variant.pval < 1e-08
#     AND gene.name is not null
#     RETURN gwas.id, gwas_to_variant.beta, gwas_to_variant.pval, gwas_to_variant.samplesize as sampleSize,
#            variant.name, gene.name, protein.uniprot_id,
#            collect (pathway.name) as Pathways, count (pathway.name) as N_pathways
#     ORDER BY gwas_to_variant.pval
#
# 17

# %%
# for neo4j browser to make a viz

#MATCH (gwas:Gwas) -[gwas_to_variant:GWAS_TO_VARIANT]->(variant:Variant)-[variant_to_gene:VARIANT_TO_GENE]-> (gene:Gene)-[gene_to_protein:GENE_TO_PROTEIN]->(protein:Protein) -[protein_in_pathway:PROTEIN_IN_PATHWAY]->(pathway:Pathway) 
#WHERE gwas.id = 'ieu-a-1126' AND gwas_to_variant.pval < 1e-08 
#AND gene.name is not null 
#RETURN gwas, gwas_to_variant, variant,variant_to_gene,  gene, gene_to_protein, protein, protein_in_pathway, pathway

Image(filename = "figures/ieu-a-1126_pathways.png")

# %%
bc_all_gwas_to_path
# Out:
#        gwas.id  gwas_to_variant.beta  gwas_to_variant.pval  sampleSize  \
# 0   ieu-a-1126               -0.2030         1.000000e-200      228951
# 1   ieu-a-1126               -0.0968          6.501297e-42      228951
# 2   ieu-a-1126                0.1206          9.038576e-35      228951
# 3   ieu-a-1126               -0.0717          4.680584e-31      228951
# 4   ieu-a-1126                0.0663          1.307073e-26      228951
# 5   ieu-a-1126               -0.0624          3.500258e-23      228951
# 6   ieu-a-1126               -0.0651          4.046691e-21      228951
# 7   ieu-a-1126               -0.0615          2.381771e-20      228951
# 8   ieu-a-1126               -0.0586          3.874360e-20      228951
# 9   ieu-a-1126                0.0567          9.074026e-19      228951
# 10  ieu-a-1126               -0.0565          3.969173e-18      228951
# 11  ieu-a-1126               -0.0741          1.284103e-15      228951
# 12  ieu-a-1126                0.2727          3.100273e-15      228951
# 13  ieu-a-1126                0.0497          1.138938e-14      228951
# 14  ieu-a-1126                0.1376          1.645887e-14      228951
# 15  ieu-a-1126                0.0465          5.436257e-14      228951
# 16  ieu-a-1126               -0.0475          1.029912e-13      228951
# 17  ieu-a-1126               -0.0465          1.195088e-13      228951
# 18  ieu-a-1126                0.1352          1.270867e-13      228951
# 19  ieu-a-1126               -0.0478          1.653103e-13      228951
# 20  ieu-a-1126                0.0791          2.190786e-13      228951
# 21  ieu-a-1126                0.0791          2.190786e-13      228951
# 22  ieu-a-1126                0.0520          6.130558e-13      228951
# 23  ieu-a-1126                0.0521          7.076198e-13      228951
# 24  ieu-a-1126                0.0463          8.207294e-13      228951
# 25  ieu-a-1126                0.0439          1.345860e-12      228951
# 26  ieu-a-1126                0.0439          1.345860e-12      228951
# 27  ieu-a-1126               -0.0595          1.618080e-12      228951
# 28  ieu-a-1126               -0.0468          2.930218e-12      228951
# 29  ieu-a-1126                0.0623          2.990198e-12      228951
# 30  ieu-a-1126               -0.0545          4.451435e-12      228951
# 31  ieu-a-1126               -0.0686          5.050100e-12      228951
# 32  ieu-a-1126               -0.0686          5.050100e-12      228951
# 33  ieu-a-1126               -0.0611          5.427502e-12      228951
# 34  ieu-a-1126                0.0445          6.313933e-12      228951
# 35  ieu-a-1126                0.0450          1.205869e-11      228951
# 36  ieu-a-1126                0.0494          1.847141e-11      228951
# 37  ieu-a-1126                0.0433          3.126799e-11      228951
# 38  ieu-a-1126               -0.0424          3.625768e-11      228951
# 39  ieu-a-1126                0.0559          3.875252e-11      228951
# 40  ieu-a-1126                0.0424          4.825030e-11      228951
# 41  ieu-a-1126               -0.0717          7.454182e-11      228951
# 42  ieu-a-1126               -0.0418          1.138990e-10      228951
# 43  ieu-a-1126               -0.0671          3.480968e-10      228951
# 44  ieu-a-1126                0.0603          1.033999e-09      228951
# 45  ieu-a-1126                0.0758          1.916991e-09      228951
# 46  ieu-a-1126                0.0383          3.210998e-09      228951
# 47  ieu-a-1126                0.0366          3.355985e-09      228951
# 48  ieu-a-1126               -0.0449          3.903013e-09      228951
# 49  ieu-a-1126                0.0472          4.126007e-09      228951
# 50  ieu-a-1126               -0.0384          7.554053e-09      228951
# 51  ieu-a-1126               -0.0384          7.554053e-09      228951
# 52  ieu-a-1126               -0.0439          7.741944e-09      228951
#
#    variant.name gene.name protein.uniprot_id  \
# 0     rs7895676     FGFR2             P21802
# 1    rs11624333    RAD51B             O15315
# 2     rs5995875      MKL1             Q969V6
# 3    rs11135046      EBF1             Q9UH73
# 4     rs2747652      ESR1             P03372
# 5    rs62048402       FTO             Q9C0B1
# 6     rs2853669      TERT             O14746
# 7     rs2506889     PEX14             O75381
# 8     rs1685191     KCNN4             O15554
# 9     rs6787391     ITPR1             Q14643
# 10    rs3769821     CASP8             Q14790
# 11   rs77554484      PRC1             O43663
# 12   rs11571833     BRCA2             P51587
# 13   rs11205303    OTUD7B             Q6GQQ9
# 14   rs72755295      EXO1             Q9UQ84
# 15   rs10885405    TCF7L2             Q9NQB0
# 16    rs4820318    PLA2G6             O60733
# 17     rs418053    RANBP9             Q96S59
# 18   rs76956704      ESR1             P03372
# 19    rs9952980   SLC14A2             Q15849
# 20    rs5997389     CHEK2             O96017
# 21    rs5997389      HSCB             Q8IWL3
# 22    rs6815814      TLR1             Q15399
# 23    rs4081859     ATG10             Q9H0Y0
# 24     rs941764   CCDC88C             Q9P219
# 25    rs6597981  SLC25A22             Q9H936
# 26    rs6597981      PIDD             Q9HB75
# 27   rs78440108      RIN3             Q8TB24
# 28    rs6725517     ADCY3             O60266
# 29    rs3821902     ATXN7             O15265
# 30   rs62485509   ARHGEF5             Q12774
# 31   rs71559437      CUX1             P39880
# 32   rs71559437      CUX1             Q13948
# 33   rs78381082    KANSL1             Q7Z3B3
# 34    rs2965183   GATAD2A             Q86YP4
# 35   rs12487185    TGFBR2             P37173
# 36   rs62331150      TET2             Q6N021
# 37    rs2253012  SLC25A21             Q9BQT8
# 38   rs56971155       FTO             Q9C0B1
# 39   rs72725173    RAD51B             O15315
# 40    rs4971059    TRIM46             Q7Z4K8
# 41   rs12546444     ZFPM2             Q8WW38
# 42    rs8082452      CBX8             Q9HC52
# 43    rs1498608     PDE4D             Q08499
# 44   rs78425380     GRHL1             Q9NZI5
# 45   rs16991615      MCM8             Q9UJA3
# 46   rs10054203      TERT             O14746
# 47    rs9284657   FAM175A             Q6UWZ7
# 48   rs11117758     ESRRG             P62508
# 49   rs11672660      GIPR             P48546
# 50    rs1778523    RNF115             Q9Y4L5
# 51    rs1778523     CD160             O95971
# 52    rs6596100     HSPA4             P34932
#
#                                              Pathways  N_pathways
# 0   [Signaling by FGFR2 fusions, Signaling by FGFR...           9
# 1   [Factors involved in megakaryocyte development...          12
# 2   [Post-translational protein modification, RHO ...           9
# 3   [Transcriptional regulation of white adipocyte...           2
# 4   [Estrogen-dependent gene expression, Extra-nuc...          34
# 5   [Reversal of alkylation damage by DNA dioxygen...           3
# 6   [Chromosome Maintenance, Formation of the beta...           9
# 7   [Protein localization, Class I peroxisomal mem...           7
# 8   [Potassium Channels, Ca2+ activated K+ channel...           3
# 9   [Signaling by the B Cell Receptor (BCR), Antig...          50
# 10  [Defective RIPK1-mediated regulated necrosis, ...          42
# 11  [RHO GTPases activate CIT, RHO GTPase Effector...           4
# 12  [Meiotic recombination, DNA Repair, Presynapti...          14
# 13  [TNF signaling, Death Receptor Signalling, Pos...          10
# 14  [Gene expression (Transcription), DNA Repair, ...          25
# 15  [RUNX3 regulates WNT signaling, Transcriptiona...          24
# 16  [Golgi-to-ER retrograde transport, Intra-Golgi...          16
# 17  [Nervous system development, FLT3 Signaling, S...          14
# 18  [Estrogen-dependent gene expression, Extra-nuc...          34
# 19  [SLC-mediated transmembrane transport, Transpo...           3
# 20  [Chk1/Chk2(Cds1) mediated inactivation of Cycl...          25
# 21  [Protein localization, Metabolism, Mitochondri...           4
# 22  [Class I MHC mediated antigen processing & pre...          21
# 23                        [Autophagy, Macroautophagy]           2
# 24  [Negative regulation of TCF-dependent signalin...           4
# 25  [Organic anion transporters, SLC-mediated tran...           4
# 26  [Gene expression (Transcription), RNA Polymera...           6
# 27  [Rab regulation of trafficking, RAB GEFs excha...           4
# 28  [Activation of GABAB receptors, GABA B recepto...          40
# 29  [Post-translational protein modification, Ub-s...           7
# 30  [Death Receptor Signalling, G alpha (12/13) si...          10
# 31  [Diseases of signal transduction by growth fac...           6
# 32  [Intra-Golgi and retrograde Golgi-to-ER traffi...           4
# 33  [Chromatin organization, Chromatin modifying e...           3
# 34  [SARS-CoV Infections, Potential therapeutics f...          24
# 35  [Signaling by TGFB family members, Post-transl...          21
# 36  [Gene expression (Transcription), TET1,2,3 and...           3
# 37  [Metabolism of amino acids and derivatives, Ly...           3
# 38  [Reversal of alkylation damage by DNA dioxygen...           3
# 39  [Factors involved in megakaryocyte development...          12
# 40  [Interferon Signaling, Interferon gamma signal...           4
# 41  [Factors involved in megakaryocyte development...           2
# 42  [Intracellular signaling by second messengers,...          23
# 43  [G alpha (i) signalling events, G alpha (s) si...           7
# 44  [Metabolism of lipids, Regulation of lipid met...           4
# 45  [Cell Cycle Checkpoints, G2/M Checkpoints, DNA...          21
# 46  [Chromosome Maintenance, Formation of the beta...           9
# 47  [DNA Repair, Cell Cycle Checkpoints, G2/M Chec...          16
# 48  [Gene expression (Transcription), RNA Polymera...           4
# 49  [Leishmania parasite growth and survival, Anti...          13
# 50  [Class I MHC mediated antigen processing & pre...           4
# 51  [Immunoregulatory interactions between a Lymph...           3
# 52  [Cellular responses to external stimuli, Cellu...           4

# %%
from matplotlib_venn import venn3
from matplotlib import pyplot as plt
# %matplotlib inline

# variants overlap between 3 GWAS
venn3([set(bc_all_gwas_to_path["variant.name"]),
       set(bc_er_pos_gwas_to_path["variant.name"]), 
       set(bc_er_neg_gwas_to_path["variant.name"])],
      set_labels=('Breast cancer All', 
                  'Breast cancer ER+', 
                  'Breast cancer ER-'))
plt.show()

# %%
#genes overlap between 3 GWAS
venn3([set(bc_all_gwas_to_path["gene.name"]), 
       set(bc_er_pos_gwas_to_path["gene.name"]), 
       set(bc_er_neg_gwas_to_path["gene.name"])],
      set_labels=('Breast cancer All',
                  'Breast cancer ER+', 
                  'Breast cancer ER-'))
plt.show()

# %%
# pathways overlap
def flatten(nested_list):
    flat_list = [item for sublist in list(nested_list) for item in sublist]
    return set(flat_list)

venn3([flatten(bc_all_gwas_to_path["Pathways"]),
      flatten(bc_er_pos_gwas_to_path["Pathways"]), 
      flatten(bc_er_neg_gwas_to_path["Pathways"])],
      set_labels=('Breast cancer All', 
                  'Breast cancer ER+', 
                  'Breast cancer ER-'))
plt.show()

# %% [markdown]
# ## Explore gwas->variant->gene->tissue

# %%
# find GWAS variants pval < 1e-05, map to genes, get expression data,
# find which are expressed in Breast tissue, with TPM > 1

def get_gwas_to_tissue(GWAS_ID):
    query = """
    MATCH (gwas:Gwas) -[gwas_to_variant:GWAS_TO_VARIANT]->(variant:Variant)-[variant_to_gene:VARIANT_TO_GENE]-> (gene:Gene)-[gene_to_tissue:EXPRESSED_IN]->(tissue:Tissue) 
    WHERE gwas.id in {}
    AND gwas_to_variant.pval < 1e-05 
    AND gene.name is not null 
    AND gene_to_tissue.tpm > 1
    AND  tissue.name = "Breast - Mammary Tissue"
    RETURN gwas.id, gwas_to_variant.beta, gwas_to_variant.pval, 
    variant.name, gene.name, 
    gene_to_tissue.tpm as TPM, tissue.name
    ORDER BY TPM desc
    """.format(GWAS_ID)

    df = query_to_df(session, query)
    return df

bc_all_exp = get_gwas_to_tissue(GWAS_ID = ['ieu-a-1126','ieu-a-1127','ieu-a-1128'] )
bc_all_exp

# these are genes that have evidence of effect on BC in GWAS, and are also expressed in breast tissue
# Out:
#     MATCH (gwas:Gwas) -[gwas_to_variant:GWAS_TO_VARIANT]->(variant:Variant)-[variant_to_gene:VARIANT_TO_GENE]-> (gene:Gene)-[gene_to_tissue:EXPRESSED_IN]->(tissue:Tissue)
#     WHERE gwas.id in ['ieu-a-1126', 'ieu-a-1127', 'ieu-a-1128']
#     AND gwas_to_variant.pval < 1e-05
#     AND gene.name is not null
#     AND gene_to_tissue.tpm > 1
#     AND  tissue.name = "Breast - Mammary Tissue"
#     RETURN gwas.id, gwas_to_variant.beta, gwas_to_variant.pval,
#     variant.name, gene.name,
#     gene_to_tissue.tpm as TPM, tissue.name
#     ORDER BY TPM desc
#         gwas.id  gwas_to_variant.beta  gwas_to_variant.pval variant.name  \
# 0    ieu-a-1126                0.0450          1.205869e-11   rs12487185
# 1    ieu-a-1127                0.0624          5.783623e-15   rs17838698
# 2    ieu-a-1127                0.0918          2.332975e-08   rs35383942
# 3    ieu-a-1126                0.1010          3.793150e-13   rs35383942
# 4    ieu-a-1127               -0.0740          4.796230e-12   rs12110303
# ..          ...                   ...                   ...          ...
# 162  ieu-a-1126                0.1046          1.612130e-63    rs7626742
# 163  ieu-a-1127                0.1148          3.278687e-54     rs490706
# 164  ieu-a-1127                0.0519          1.265028e-11    rs4971059
# 165  ieu-a-1126                0.0424          4.825030e-11    rs4971059
# 166  ieu-a-1128                0.1550          1.249971e-37   rs56069439
#
#     gene.name       TPM              tissue.name
# 0      TGFBR2  273.1000  Breast - Mammary Tissue
# 1      TGFBR2  273.1000  Breast - Mammary Tissue
# 2      PHLDA3  118.1500  Breast - Mammary Tissue
# 3      PHLDA3  118.1500  Breast - Mammary Tissue
# 4      ARRDC3   73.8650  Breast - Mammary Tissue
# ..        ...       ...                      ...
# 162     NEK10    1.2100  Breast - Mammary Tissue
# 163     NEK10    1.2100  Breast - Mammary Tissue
# 164    TRIM46    1.0800  Breast - Mammary Tissue
# 165    TRIM46    1.0800  Breast - Mammary Tissue
# 166    ANKLE1    1.0235  Breast - Mammary Tissue
#
# [167 rows x 7 columns]

# %%
# add expression level categories
bc_all_exp['tpm_category'] = ''
bc_all_exp

for ind in bc_all_exp.index:
    if bc_all_exp['TPM'][ind] >= 100:
        bc_all_exp['tpm_category'][ind] = "high"
    elif bc_all_exp['TPM'][ind] < 100 and bc_all_exp['TPM'][ind] > 10 :
        bc_all_exp['tpm_category'][ind] = "medium"
    elif bc_all_exp['TPM'][ind] <= 10:
        bc_all_exp['tpm_category'][ind] = "low"
        
bc_all_exp
# Out:
# /Users/ny19205/opt/anaconda3/envs/neo4j_build/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/ny19205/opt/anaconda3/envs/neo4j_build/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/ny19205/opt/anaconda3/envs/neo4j_build/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#         gwas.id  gwas_to_variant.beta  gwas_to_variant.pval variant.name  \
# 0    ieu-a-1126                0.0450          1.205869e-11   rs12487185
# 1    ieu-a-1127                0.0624          5.783623e-15   rs17838698
# 2    ieu-a-1127                0.0918          2.332975e-08   rs35383942
# 3    ieu-a-1126                0.1010          3.793150e-13   rs35383942
# 4    ieu-a-1127               -0.0740          4.796230e-12   rs12110303
# ..          ...                   ...                   ...          ...
# 162  ieu-a-1126                0.1046          1.612130e-63    rs7626742
# 163  ieu-a-1127                0.1148          3.278687e-54     rs490706
# 164  ieu-a-1127                0.0519          1.265028e-11    rs4971059
# 165  ieu-a-1126                0.0424          4.825030e-11    rs4971059
# 166  ieu-a-1128                0.1550          1.249971e-37   rs56069439
#
#     gene.name       TPM              tissue.name tpm_category
# 0      TGFBR2  273.1000  Breast - Mammary Tissue         high
# 1      TGFBR2  273.1000  Breast - Mammary Tissue         high
# 2      PHLDA3  118.1500  Breast - Mammary Tissue         high
# 3      PHLDA3  118.1500  Breast - Mammary Tissue         high
# 4      ARRDC3   73.8650  Breast - Mammary Tissue       medium
# ..        ...       ...                      ...          ...
# 162     NEK10    1.2100  Breast - Mammary Tissue          low
# 163     NEK10    1.2100  Breast - Mammary Tissue          low
# 164    TRIM46    1.0800  Breast - Mammary Tissue          low
# 165    TRIM46    1.0800  Breast - Mammary Tissue          low
# 166    ANKLE1    1.0235  Breast - Mammary Tissue          low
#
# [167 rows x 8 columns]

# %%
bc_all_exp.to_csv("query_results/bc_gwas_expressed_in_breastTissue.tsv", sep="\t", index=False)

# %%
gene_list = list(set(bc_all_exp['gene.name']))
len(gene_list)
# Out:
# 98

# %%
# map to their protein product
query="""
MATCH  (gene:Gene)-[gene_to_protein:GENE_TO_PROTEIN]->(protein:Protein) 
WHERE gene.name in {}
RETURN  gene.name, protein.name
""".format(gene_list)
df=query_to_df(session, query)
df
# Out:
# MATCH  (gene:Gene)-[gene_to_protein:GENE_TO_PROTEIN]->(protein:Protein)
# WHERE gene.name in ['PEX14', 'NRIP1', 'ELL', 'RP11-134G8.8', 'PRC1', 'VGLL3', 'CDYL2', 'ABO', 'TGFBR2', 'RCCD1', 'N4BP2L1', 'CASP8', 'KCNN4', 'PLA2G6', 'PDE4D', 'CBX8', 'AMFR', 'TTC28', 'MLLT10', 'SCAMP2', 'LSP1', 'MTMR11', 'ITPR1', 'ZMIZ1', 'RIN3', 'ANKLE1', 'FAM46A', 'KANSL1', 'FILIP1L', 'TRIM46', 'SETBP1', 'ADCY3', 'CUX1', 'SSBP4', 'ARHGEF5', 'ATG10', 'SLC25A22', 'L3MBTL3', 'GRHL1', 'OTUD7B', 'VPS33B', 'FOXP1', 'PIDD', 'TLR1', 'MYEOV', 'PIK3R3', 'PHLDA3', 'TACC2', 'TCF7L2', 'MCM8', 'ADSSL1', 'EBF1', 'HSPA4', 'SF3B4', 'LGR6', 'FGFR2', 'NEK10', 'NREP', 'ASTN2', 'CDCA7L', 'ZNF184', 'USHBP1', 'RPL23AP53', 'ESR1', 'KRTCAP2', 'ZBTB38', 'CREB5', 'ULK3', 'RAD51B', 'FAM175A', 'ATXN7', 'DNAJC1', 'SV2A', 'OR2A1-AS1', 'ARRDC3', 'FTO', 'TET2', 'LINC-PINT', 'GIPR', 'HSCB', 'CHEK2', 'ADCY9', 'SUB1', 'MDM4', 'ZFPM2', 'MKL1', 'STXBP4', 'BABAM1', 'CMSS1', 'RNF115', 'GAREM', 'RANBP9', 'GATAD2A', 'MAGI3', 'CDKN2B', 'LMX1B', 'CCDC88C', 'ATAD5']
# RETURN  gene.name, protein.name
#    gene.name protein.name
# 0      NRIP1       P48552
# 1      RCCD1       A6NED2
# 2       PRC1       O43663
# 3     VPS33B       Q9H267
# 4      LMX1B       O60663
# ..       ...          ...
# 89    RNF115       Q9Y4L5
# 90    MLLT10       P55197
# 91    PHLDA3       Q9Y5J5
# 92    DNAJC1       Q96KC8
# 93      LGR6       Q9HBX8
#
# [94 rows x 2 columns]

# %%
# take genes expressed in Breast tissues and  collect where they are also expressed
# not really sure what to do with this information

genes_test=list(bc_all_exp['gene.name'])

query = """
    MATCH (gene:Gene)-[gene_to_tissue:EXPRESSED_IN]->(tissue:Tissue) 
    WHERE gene.name in {} 
    AND gene_to_tissue.tpm > 1
    WITH gene_to_tissue, gene, tissue
    ORDER BY gene_to_tissue.tpm  desc, tissue.name
    RETURN gene.name, count(tissue.name) as N_tissues, 
    collect(tissue.name) as Tissues, collect(gene_to_tissue.tpm) as TPM_vals
    """.format(genes_test)

df = query_to_df(session, query)
df
# Out:
#     MATCH (gene:Gene)-[gene_to_tissue:EXPRESSED_IN]->(tissue:Tissue)
#     WHERE gene.name in ['TGFBR2', 'TGFBR2', 'PHLDA3', 'PHLDA3', 'ARRDC3', 'SCAMP2', 'BABAM1', 'SF3B4', 'ADCY3', 'ADCY3', 'SUB1', 'ULK3', 'SSBP4', 'KRTCAP2', 'KRTCAP2', 'AMFR', 'TCF7L2', 'TCF7L2', 'ZMIZ1', 'ZMIZ1', 'ZMIZ1', 'ZMIZ1', 'EBF1', 'EBF1', 'EBF1', 'RANBP9', 'RANBP9', 'HSPA4', 'HSPA4', 'PIK3R3', 'PIK3R3', 'MKL1', 'MKL1', 'MKL1', 'KANSL1', 'LSP1', 'LSP1', 'PLA2G6', 'PLA2G6', 'DNAJC1', 'PEX14', 'PEX14', 'PEX14', 'GATAD2A', 'FILIP1L', 'FILIP1L', 'ELL', 'HSCB', 'HSCB', 'N4BP2L1', 'N4BP2L1', 'PIDD', 'MDM4', 'MLLT10', 'MLLT10', 'MLLT10', 'NRIP1', 'RNF115', 'RNF115', 'GRHL1', 'VPS33B', 'ZBTB38', 'ZBTB38', 'USHBP1', 'ITPR1', 'ITPR1', 'LINC-PINT', 'ATXN7', 'ATXN7', 'FOXP1', 'SLC25A22', 'VGLL3', 'FAM46A', 'FAM46A', 'FAM46A', 'MTMR11', 'CMSS1', 'CMSS1', 'CDKN2B', 'ADCY9', 'TTC28', 'TTC28', 'SETBP1', 'SETBP1', 'RIN3', 'TACC2', 'RP11-134G8.8', 'RP11-134G8.8', 'RCCD1', 'CCDC88C', 'CCDC88C', 'CCDC88C', 'CUX1', 'CUX1', 'GIPR', 'GIPR', 'FGFR2', 'FGFR2', 'FGFR2', 'OTUD7B', 'KCNN4', 'KCNN4', 'L3MBTL3', 'L3MBTL3', 'ADSSL1', 'CASP8', 'CASP8', 'CASP8', 'FTO', 'FTO', 'FTO', 'FTO', 'CREB5', 'CDCA7L', 'GAREM', 'ZFPM2', 'ZFPM2', 'MAGI3', 'ESR1', 'ESR1', 'ESR1', 'ESR1', 'ESR1', 'ZNF184', 'TET2', 'TET2', 'MCM8', 'LMX1B', 'LGR6', 'ARHGEF5', 'ARHGEF5', 'CDYL2', 'CDYL2', 'CHEK2', 'CHEK2', 'FAM175A', 'MYEOV', 'ABO', 'PRC1', 'PRC1', 'PDE4D', 'RPL23AP53', 'ATG10', 'ATG10', 'SV2A', 'NREP', 'TLR1', 'TLR1', 'CBX8', 'OR2A1-AS1', 'OR2A1-AS1', 'STXBP4', 'STXBP4', 'ATAD5', 'ATAD5', 'RAD51B', 'RAD51B', 'RAD51B', 'RAD51B', 'RAD51B', 'ASTN2', 'ASTN2', 'NEK10', 'NEK10', 'TRIM46', 'TRIM46', 'ANKLE1']
#     AND gene_to_tissue.tpm > 1
#     WITH gene_to_tissue, gene, tissue
#     ORDER BY gene_to_tissue.tpm  desc, tissue.name
#     RETURN gene.name, count(tissue.name) as N_tissues,
#     collect(tissue.name) as Tissues, collect(gene_to_tissue.tpm) as TPM_vals
#     gene.name  N_tissues                                            Tissues  \
# 0        LSP1         42  [Whole Blood, Cells - EBV-transformed lymphocy...
# 1      PHLDA3         51  [Nerve - Tibial, Colon - Sigmoid, Adipose - Su...
# 2      TGFBR2         52  [Adipose - Subcutaneous, Adipose - Visceral (O...
# 3      ADSSL1         50  [Muscle - Skeletal, Artery - Tibial, Artery - ...
# 4        ULK3         52  [Brain - Cerebellum, Brain - Cerebellar Hemisp...
# ..        ...        ...                                                ...
# 93      ATG10         51  [Testis, Skin - Not Sun Exposed (Suprapubic), ...
# 94  RPL23AP53         50  [Testis, Artery - Tibial, Ovary, Artery - Aort...
# 95      LMX1B          8  [Breast - Mammary Tissue, Skin - Sun Exposed (...
# 96     RAD51B         21  [Uterus, Cells - EBV-transformed lymphocytes, ...
# 97     STXBP4         37  [Artery - Tibial, Nerve - Tibial, Cervix - Ect...
#
#                                              TPM_vals
# 0   [418.8, 236.7, 165.85, 105.15, 57.02, 53.04, 4...
# 1   [352.75, 195.0, 183.15, 118.15, 117.8, 113.9, ...
# 2   [316.8, 296.1, 273.1, 260.05, 252.3, 244.4, 22...
# 3   [311.15, 63.53, 58.37, 54.49, 52.2, 44.51, 19....
# 4   [259.2, 249.9, 135.0, 130.0, 116.0, 105.7, 104...
# ..                                                ...
# 93  [6.895, 3.824, 3.7855, 3.7560000000000002, 3.6...
# 94  [6.215, 6.184, 6.021, 5.747000000000001, 5.654...
# 95  [5.348, 3.0789999999999997, 2.763, 2.68, 2.498...
# 96  [5.187, 4.0765, 3.2539999999999996, 3.19100000...
# 97  [4.0360000000000005, 3.8935, 3.7885, 3.675, 3....
#
# [98 rows x 4 columns]

# %%
# e.g. just try one gene
query = """
    MATCH (gene:Gene)-[gene_to_tissue:EXPRESSED_IN]->(tissue:Tissue) 
    WHERE gene.name = 'LMX1B' 
    AND gene_to_tissue.tpm > 1
    RETURN gene.name, gene_to_tissue.tpm, tissue.name 
    ORDER BY gene_to_tissue.tpm desc
    """

df = query_to_df(session, query)
df
# Out:
#     MATCH (gene:Gene)-[gene_to_tissue:EXPRESSED_IN]->(tissue:Tissue)
#     WHERE gene.name = 'LMX1B'
#     AND gene_to_tissue.tpm > 1
#     RETURN gene.name, gene_to_tissue.tpm, tissue.name
#     ORDER BY gene_to_tissue.tpm desc
#   gene.name  gene_to_tissue.tpm                          tissue.name
# 0     LMX1B              5.3480              Breast - Mammary Tissue
# 1     LMX1B              3.0790       Skin - Sun Exposed (Lower leg)
# 2     LMX1B              2.7630                      Kidney - Cortex
# 3     LMX1B              2.6800                               Testis
# 4     LMX1B              2.4980  Skin - Not Sun Exposed (Suprapubic)
# 5     LMX1B              2.4345             Brain - Substantia nigra
# 6     LMX1B              1.1880             Heart - Atrial Appendage
# 7     LMX1B              1.0270                 Minor Salivary Gland
